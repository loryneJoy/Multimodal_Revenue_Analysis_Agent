# %% [markdown]
# <a href="https://colab.research.google.com/github/loryneJoy/Multimodal_Revenue_Analysis_Agent/blob/main/Multimodal_Revenue_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PROJECT TASK
# #### come up with their a multimodal agent. It should take an image and text, then give back an output

# %% [markdown]
# ### STEPS I TOOK:
# 1. Data source (PDF File) extract images and text
# 2. Convert text into chunks and perform embedding
# 3. Perform embedding on the images using clip model by OpenAI
# 4. Store images in the base 64 format
# 5. Store both text and image embeddings in vector stores (FAISS vector store)
# 6. Clip embedding (convert query into an embedding) (CLIP is Contrastive Language - Image Pre-training). Clip has combination of visual transformer and text transformer
# 7. Retriever - is a vector store from FAISS
# 8. Convert text image information to specific formatt
# 9. Pass to an LLM model
# 10. Get the multimodal answer

# %% [markdown]
# :#### Step 1: Extracting images and text by use of PyMuPDF(fitz)

# %%
# %pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.30-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.3.76)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.43)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.28)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.30-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 16.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.3.30 marshmallow-3.26.1 mypy-extensions-1.1.0 requests-2.32.5 typing-inspect-0.9.0

# %%
# %pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 69.8 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.4

# %%
# Importing Libraries
import fitz  # PyMuPDF
from langchain_core.documents import Document
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import numpy as np
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.schema.messages import HumanMessage
from sklearn.metrics.pairwise import cosine_similarity
import os
import base64
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %% [markdown]
# #### Load the CLIP Models

# %%
from dotenv import load_dotenv
load_dotenv()

import os

# %%
# Clip Model
import os
from dotenv import load_dotenv
load_dotenv()

# set up the environment
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# initialize the Clip Model for unified embeddings - huggingface
clip_model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %% [markdown]
# ### EMBEDDING

# %%
### Embedding functions
def embed_image(image_data):
    """Embed image using CLIP"""
    if isinstance(image_data, str):  # If path
        image = Image.open(image_data).convert("RGB")
    else:  # If PIL Image
        image = image_data

    inputs=clip_processor(images=image,return_tensors="pt")
    with torch.no_grad():
        features = clip_model.get_image_features(**inputs)
        # Normalize embeddings to unit vector
        features = features / features.norm(dim=-1, keepdim=True)
        return features.squeeze().numpy()

def embed_text(text):
    """Embed text using CLIP."""
    inputs = clip_processor(
        text=text,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=77  # CLIP's max token length
    )
    with torch.no_grad():
        features = clip_model.get_text_features(**inputs)
        # Normalize embeddings
        features = features / features.norm(dim=-1, keepdim=True)
        return features.squeeze().numpy()

# %%
## Process PDF
pdf_path="/content/Cost_Revenue_Analysis.pdf"
doc=fitz.open(pdf_path)
# Storage for all documents and embeddings
all_docs = []
all_embeddings = []
image_data_store = {}  # Store actual image data for LLM

# Text splitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

# %%
doc
# Out:
# Document('/content/Cost_Revenue_Analysis.pdf')

# %%
for i,page in enumerate(doc):
    ## process text
    text=page.get_text()
    if text.strip():
        ##create temporary document for splitting
        temp_doc = Document(page_content=text, metadata={"page": i, "type": "text"})
        text_chunks = splitter.split_documents([temp_doc])

        #Embed each chunk using CLIP
        for chunk in text_chunks:
            embedding = embed_text(chunk.page_content)
            all_embeddings.append(embedding)
            all_docs.append(chunk)



    # processing the images
    # Three Important Steps include:

    # Convert PDF image to PIL format
    # Store as base64 for GPT-4V (which needs base64 images)
    # Create CLIP embedding for retrieval

    for img_index, img in enumerate(page.get_images(full=True)):
        try:
            xref = img[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]

            # Convert to PIL Image
            pil_image = Image.open(io.BytesIO(image_bytes)).convert("RGB")

            # Create unique identifier
            image_id = f"page_{i}_img_{img_index}"

            # Store image as base64 for later use with GPT-4V
            buffered = io.BytesIO()
            pil_image.save(buffered, format="PNG")
            img_base64 = base64.b64encode(buffered.getvalue()).decode()
            image_data_store[image_id] = img_base64

            # Embed image using CLIP
            embedding = embed_image(pil_image)
            all_embeddings.append(embedding)

            # Create document for image
            image_doc = Document(
                page_content=f"[Image: {image_id}]",
                metadata={"page": i, "type": "image", "image_id": image_id}
            )
            all_docs.append(image_doc)

        except Exception as e:
            print(f"Error processing image {img_index} on page {i}: {e}")
            continue

doc.close()

# %%
all_docs
# Out:
# [Document(metadata={'page': 0, 'type': 'text'}, page_content='|  393 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST AND REVENUE ANALYSIS\nHow to produce par-al proﬁtability informa-on'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_0'}, page_content='[Image: page_0_img_0]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_1'}, page_content='[Image: page_0_img_1]'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='|  394 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\nOPHYSICAL\nIPHYSICAL\nOREVENUES\nIEXPENSES\na) Partial \nb) Total \na) Partial\nb) Total'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_0'}, page_content='[Image: page_1_img_0]'),
#  Document(metadata={'page': 2, 'type': 'text'}, page_content='|  395 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\na) Partial \x01\nb) Total \x02\na) Partial \x02\nb) Total \x01\nJUST THE OPPOSITE'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_0'}, page_content='[Image: page_2_img_0]'),
#  Document(metadata={'page': 3, 'type': 'text'}, page_content='|  396 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales revenues\n265.780\n€        \n100,00%\n- Cost of goods sold (@manufacturing variable cost)\n85.330\n-€          \n-32,11%\n= Manufacturing variable margin\n180.450\n€        \n67,89%\n- Sales variable costs\n24.550\n-€          \n-9,24%\n= Contribution margin\n155.900\n€        \n58,66%\n- Fixed costs (excluding depreciation and amortization costs)\n83.009\n-€          \n-31,23%\n= EBITDA\n72.891\n€          \n27,43%'),
#  Document(metadata={'page': 3, 'type': 'text'}, page_content='83.009\n-€          \n-31,23%\n= EBITDA\n72.891\n€          \n27,43%\n- Depreciation and amortization costs\n38.126\n-€          \n-14,34%\n= EBIT\n34.765\n€          \n13,08%\n- Interst expenses\n12.500\n-€          \n-4,70%\n= EBT\n22.265\n€          \n8,38%\n- Income taxes\n6.680\n-€            \n-2,51%\n= EAT\n15.586\n€          \n5,86%\nDIFFERENT POSSIBLE PROFIT MARGINS'),
#  Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_0'}, page_content='[Image: page_3_img_0]'),
#  Document(metadata={'page': 4, 'type': 'text'}, page_content='|  397 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales Revenues\n– Cost of Goods Sold\n= Gross Margin\n– S,G&A Expenses\n= EBIT\n– Interest Expenses\n= EBT\nBoard of \nDirector\nR&D\nOperations\nPurchasing \nProduction\nMarketing & \nSales\nMarketing\nSales\nAccounting & \nFinance\nAccounting\nFinance\nHR\nSOME IMPORTANT RELATIONSHIPS'),
#  Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_0'}, page_content='[Image: page_4_img_0]'),
#  Document(metadata={'page': 5, 'type': 'text'}, page_content='|  398 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nProduct "A"\n657.235\n€        \nCustomer "X"\n432.001\n€        \nResponsability center "1"\n2.433.015\n€     \nProduct "B"\n546.763\n€        \nCustomer "Y"\n367.455\n€        \nResponsability center "2"\n1.774.550\n€     \nProduct "C"\n432.267\n€        \nCustomer "W"\n312.826\n€        \nResponsability center "3"\n64.520\n-€          \n……...............\n…........................\n……...............\n…........................\n……...............'),
#  Document(metadata={'page': 5, 'type': 'text'}, page_content='…........................\n……...............\n…........................\n……...............\n…........................\nProduct "N"\n138.758\n-€        \nCustomer "K"\n25.789\n-€          \nResponsability center "12"\n835.519\n-€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nCOST ANALYSIS\nDIFFERENT SEGMENT\nFINANCIAL ACCOUNTING\nTotal Financial Productivity \nMANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity'),
#  Document(metadata={'page': 5, 'type': 'text'}, page_content='MANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity \nFinancial and \nnonfinancial information \nFROM TOTAL TO PARTIAL FINANCIAL PRODUCTIVITY\n+ Operating revenues\n4.207.565\n€     \n- Operating costs\n3.705.816\n-€     \n= Operating profit\n501.749\n€'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_0'}, page_content='[Image: page_5_img_0]'),
#  Document(metadata={'page': 6, 'type': 'text'}, page_content='|  399 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST OBJECTS\nGli oggetti di riferimento\n“External”\nCustomers or clusters of Customers\nDistribution Channels\nGeographical Areas\nSuppliers\n“Internal”\nResources (Means of Production)\nResponsibility Centers (Departments)\nActivities or Processes\nProjects\nWIPs\nProducts or Product Lines\nThese\ncost\nobjects\nare\nthe\nmost\ninnovative: they denote the adoption of a\nmore modern management control. The\nfocus is on the outside world.'),
#  Document(metadata={'page': 6, 'type': 'text'}, page_content='more modern management control. The\nfocus is on the outside world.\nThose who adopt this perspective seek to\nobtain\nthe\ninformation\nnecessary\nto\nmanage\nmarket\ncompetition\nmore\neffectively\nDIFFERENT COST OBJECTS'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_0'}, page_content='[Image: page_6_img_0]'),
#  Document(metadata={'page': 7, 'type': 'text'}, page_content='|  400 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales Revenues\n- Sales Commissions\n---------------------------------------------------\n= Net Revenues\n- Direct Materials\n-----------------------------------------------------\n= First Margin\n- Outsourced Work\n-----------------------------------------------------\n= Second Margin\n- Other Direct Costs\n- Direct Labor\n-----------------------------------------------------\n= Job Orders Direct Margin\nxxx\nxxx\n--------\n= xxx\n- xxx'),
#  Document(metadata={'page': 7, 'type': 'text'}, page_content='= Job Orders Direct Margin\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB 1\nJOB 2\nJOB 3\n∑\n∑\n--------\n= ∑\n∑\n--------\n= ∑\n∑\n--------\n= ∑\n- ∑\n- ∑\n--------\n= ∑\nTotal\n- Manufacturing Overhead\n- Selling Overhead Expenses\n- Administrative Expenses\n- General Expenses\n------------------------------------------------------\n= Ebit\n- xxx\n- xxx\n- xxx\n- xxx\n--------\n= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------'),
#  Document(metadata={'page': 7, 'type': 'text'}, page_content='= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB N\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB …\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nA SEGMENT INCOME STATEMENT'),
#  Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_0'}, page_content='[Image: page_7_img_0]'),
#  Document(metadata={'page': 8, 'type': 'text'}, page_content='|  401 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nWHY IT IS DIFFICULT TO COMPUTE….  \nPartial ﬁnancial productivity measure: \nRESOURCE\nCOST\nCOST OBJECT 1\nCOST OBJECT 2'),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_0'}, page_content='[Image: page_8_img_0]'),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_1'}, page_content='[Image: page_8_img_1]'),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_2'}, page_content='[Image: page_8_img_2]'),
#  Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_3'}, page_content='[Image: page_8_img_3]'),
#  Document(metadata={'page': 9, 'type': 'text'}, page_content='|  402 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\na) Partial \x01\nb) Total \x02\na) Partial \x02\nb) Total \x01\nWHY IT IS DIFFICULT TO COMPUTE….'),
#  Document(metadata={'page': 9, 'type': 'image', 'image_id': 'page_9_img_0'}, page_content='[Image: page_9_img_0]'),
#  Document(metadata={'page': 10, 'type': 'text'}, page_content='|  403 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nProduct "A"\n657.235\n€        \nCustomer "X"\n432.001\n€        \nResponsability center "1"\n2.433.015\n€     \nProduct "B"\n546.763\n€        \nCustomer "Y"\n367.455\n€        \nResponsability center "2"\n1.774.550\n€     \nProduct "C"\n432.267\n€        \nCustomer "W"\n312.826\n€        \nResponsability center "3"\n64.520\n-€          \n……...............\n…........................\n……...............\n…........................\n……...............'),
#  Document(metadata={'page': 10, 'type': 'text'}, page_content='…........................\n……...............\n…........................\n……...............\n…........................\nProduct "N"\n138.758\n-€        \nCustomer "K"\n25.789\n-€          \nResponsability center "12"\n835.519\n-€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nCOST ANALYSIS\nDIFFERENT SEGMENT\nFINANCIAL ACCOUNTING\nTotal Financial Productivity \nMANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity'),
#  Document(metadata={'page': 10, 'type': 'text'}, page_content='MANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity \nFinancial and \nnonﬁnancial information \nFROM TOTAL TO PARTIAL FINANCIAL PRODUCTIVITY\n+ Operating revenues\n4.207.565\n€     \n- Operating costs\n3.705.816\n-€     \n= Operating profit\n501.749\n€'),
#  Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_0'}, page_content='[Image: page_10_img_0]'),
#  Document(metadata={'page': 11, 'type': 'text'}, page_content='|  404 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST COLLECTION SYSTEMS \nCost accumulation is the collection of cost data in some organized way by means of\nan accounting system.\nCost collection systems typically accounts for costs in two broad stages:\n1. they initially accumulates costs classifying them “by nature”: that is to say\ninto categories that remind us the type of resources purchased or consumed'),
#  Document(metadata={'page': 11, 'type': 'text'}, page_content='into categories that remind us the type of resources purchased or consumed\n(e.g., raw materials, depreciation, transports costs, rent expenses, wages and\nsalaries, etc.). Later this criterion is combined with other two that focus their\nattention on cost behavior (ﬁxed and variable costs) or on the robustness of\nthe relation that link a cost to a speciﬁc cost objects (direct and indirect costs) .\n2. They then assign these costs to cost objects.\nCOST\nACCUMULATIONS\nCOST\nASSIGNMENT'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_0'}, page_content='[Image: page_11_img_0]'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_1'}, page_content='[Image: page_11_img_1]'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_2'}, page_content='[Image: page_11_img_2]'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_3'}, page_content='[Image: page_11_img_3]'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_4'}, page_content='[Image: page_11_img_4]'),
#  Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_5'}, page_content='[Image: page_11_img_5]'),
#  Document(metadata={'page': 12, 'type': 'text'}, page_content='|  405 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST ANALYSIS\nThe concrete implementa.on of a proper cost analysis requires to make some\nbasic decisions about the following issues:\n§\nCost Object\n§\nPeriodicity of the analysis (one .me “had hoc” versus systema.c)\n§\nPor.on of the cost base that is to be assigned to the cost object: selec.on\nof the “cost rule” that is to say of the evalua.on criterion – in terms of cost\n– for the cost object)\n§'),
#  Document(metadata={'page': 12, 'type': 'text'}, page_content='– for the cost object)\n§\nStructure of the cost ﬂow: selec.on of the proper accumula.on’s method\n§\nInput measurement base'),
#  Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_0'}, page_content='[Image: page_12_img_0]'),
#  Document(metadata={'page': 13, 'type': 'text'}, page_content='|  406 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST OBJECTS\nGli oggetti di riferimento\n“External”\nCustomers or clusters of Customers\nDistribution Channels\nGeographical Areas\nSuppliers\n“Internal”\nResources (Means of Production)\nResponsibility Centers (Departments)\nActivities or Processes\nProjects\nWIPs\nProducts or Product Lines\nThese\ncost\nobjects\nare\nthe\nmost\ninnovative: they denote the adoption of a\nmore modern management control. The\nfocus is on the outside world.'),
#  Document(metadata={'page': 13, 'type': 'text'}, page_content='more modern management control. The\nfocus is on the outside world.\nThose who adopt this perspective seek to\nobtain\nthe\ninformation\nnecessary\nto\nmanage\nmarket\ncompetition\nmore\neffectively\nDIFFERENT COST OBJECTS'),
#  Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_0'}, page_content='[Image: page_13_img_0]'),
#  Document(metadata={'page': 14, 'type': 'text'}, page_content='|  407 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nA RESOURCE AS A COST OBJECT\nlubrica(ng oil\ntyres\nmechanical parts\nbrakes\ndriving ac(vity\nrepairs and maintenance\ncasualty insurance\ngasoline\nO\nI\nhours of work performed\nPlease note: the cost of opera0ng a tractor is a compound cost consis,ng of the sum of many elementary costs. \nsome of these costs are incurred exclusively for the opera0on of the tractor (tyres deprecia0on) others, however,'),
#  Document(metadata={'page': 14, 'type': 'text'}, page_content='are also incurred for other reasons (the cost of personnel who, in addi0on to doing other things, drive the tractor).'),
#  Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_0'}, page_content='[Image: page_14_img_0]'),
#  Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_1'}, page_content='[Image: page_14_img_1]'),
#  Document(metadata={'page': 15, 'type': 'text'}, page_content='|  408 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nRELATION BETWEEN DIFFERENT COST OBJECTS\nTRACTOR\n(Resource)\nPHYTOSANITARY TREATMENTS\n(Ac,vity)\nGRAPE TRANSPORTATION \n(Activity)\nVINEYARD\n(Resource)\nGRAPE\n(WIP)\nSPRAYER\n(Resource)\nWINE\n(WIP)\nBOTTLE OF WINE\n(PRODUCT )'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_0'}, page_content='[Image: page_15_img_0]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_1'}, page_content='[Image: page_15_img_1]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_2'}, page_content='[Image: page_15_img_2]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_3'}, page_content='[Image: page_15_img_3]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_4'}, page_content='[Image: page_15_img_4]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_5'}, page_content='[Image: page_15_img_5]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_6'}, page_content='[Image: page_15_img_6]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_7'}, page_content='[Image: page_15_img_7]'),
#  Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_8'}, page_content='[Image: page_15_img_8]'),
#  Document(metadata={'page': 16, 'type': 'text'}, page_content='|  409 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nA VAN AS A RESPONSIBILITY CENTER\nlubrica0ng oil\ntyres\nmechanical parts\nbrakes\nrepairs and maintenance\ncasualty insurance\ngasoline\n€ \nbasic wage \ndearness allowance\nbonuses\nemployer’s contribu0on to \nemployees’ state insurance\nfringe beneﬁts\ncustom duty paid\ntransit insurance\ncost of goods \nloading and \nunloading charges\ncarriage paid'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_0'}, page_content='[Image: page_16_img_0]'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_1'}, page_content='[Image: page_16_img_1]'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_2'}, page_content='[Image: page_16_img_2]'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_3'}, page_content='[Image: page_16_img_3]'),
#  Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_4'}, page_content='[Image: page_16_img_4]'),
#  Document(metadata={'page': 17, 'type': 'text'}, page_content='|  410 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nVARIABLE COSTS\nFIXED COSTS\nUNITS\nTRANSACTIONS\nPRODUCTS\nCUSTOMERS\nCHANNELS\nPROJECTS\nRELATION BETWEEN DIFFERENT COST OBJECTS\nSUPPLIERS\nRESOURCES'),
#  Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_0'}, page_content='[Image: page_17_img_0]'),
#  Document(metadata={'page': 18, 'type': 'text'}, page_content='|  411 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST & REVENUES ANALYSIS\nA set of logic, criteria, methods\nand techniques for the\n² collection,\n² classiﬁcation,\n² aggregation and\n² attribution\nof costs and revenues\nSYSTEMATIC AND CONSTANT INFORMATION FLOWS\nPRODUCTION OF "AD HOC" INFORMATION\nIN RELATION TO SPECIFIC DECISION MAKING\nFinalità del calcolo dei cos. - 2\nCOST SYSTEMS\nFocused on cost-objects that are considered\nparticularly relevant for day-by-day decisions'),
#  Document(metadata={'page': 18, 'type': 'text'}, page_content='Focused on cost-objects that are considered\nparticularly relevant for day-by-day decisions\nand, therefore, that need constant monitoring\nONE-OFF COST ANALYSIS\nRelating to speciﬁc cost-objects, from time to\ntime different depending on the\ntype of\ndecision to be taken\nPERIODICITY OF THE ANALYSIS'),
#  Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_0'}, page_content='[Image: page_18_img_0]'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='|  412 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDecision to be made:\nA. Things to do in Rome \nwhile visi(ng the city as a \ntourist for a ﬁve days \nperiod \nB. Things to do in Rome \nwhile spending a six \nmonths period in the city \nfor work\n§\nDiﬀerent possible hotel/B&B \naccommoda(ons\n§\nBest restaurants in town\n§\nUnderground (ckets and weekly \npass\n§\nBest Museum\n§\nExercise drills\n§\nApartments monthly rates \n§\nConvenient grocery stores \nnearby\n§'),
#  Document(metadata={'page': 19, 'type': 'text'}, page_content='§\nBest Museum\n§\nExercise drills\n§\nApartments monthly rates \n§\nConvenient grocery stores \nnearby\n§\nUsed cars prices, buses and train \nmonthly pass \n§\nPlaces to visit in the surrounding \narea\n§\nGym and swimming pool \nmemberships\nDIFFERENT DECISIONS , DIFFERENT SETS OF INFORMATIONS'),
#  Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_0'}, page_content='[Image: page_19_img_0]'),
#  Document(metadata={'page': 20, 'type': 'text'}, page_content='|  413 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIFFERENT FUNCTIONS, DIFFERENT DEMANDS\nSOURCE: Kaplan,  “One Cost System Isn’t Enough ”, Harvard Business Review, January - February 1988\nFunctions  \nFrequency  \nAllocation  \nScope of  \nNature of \nDegree of \n \n \n \nSystem  \nVariability  \nObjectivity \nInventory  \nMonthly or  \nAggregate  \nFactory  \nIrrelevant  \nHigh \nvaluation  \nquarterly  \n \ncosts \nOperational  \nDaily, by  \nNone  \nResponsibility  \nShort-term  \nHigh \ncontrol'),
#  Document(metadata={'page': 20, 'type': 'text'}, page_content='quarterly  \n \ncosts \nOperational  \nDaily, by  \nNone  \nResponsibility  \nShort-term  \nHigh \ncontrol  \nunit of work  \n \ncenter  \nvariable \naccomplished  \n \n \nand fixed \nProduct cost  \nAnnually and  \nExtensive, down  \nEntire organization \nAll variable \nLow \nmeasurement  \nat major change  \nto individual   \nincluding marketing \npoints \nproducts or \nand distribution, \n \nproduct lines \nengineering, service, \n \n \nand administration'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_0'}, page_content='[Image: page_20_img_0]'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_1'}, page_content='[Image: page_20_img_1]'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_2'}, page_content='[Image: page_20_img_2]'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_3'}, page_content='[Image: page_20_img_3]'),
#  Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_4'}, page_content='[Image: page_20_img_4]'),
#  Document(metadata={'page': 21, 'type': 'text'}, page_content="|  414 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIFFERENT VALUATION CRETERIA FOR A PRODUCT\nNET REALIZABLE VALUE\nThe es'mated selling price in the\nordinary course of business minus\nany cost to complete and to sell\nthe goods\nVARIABLE MANUFACTURING COST\nVARIABLE COST\nThe costs necessary to convert raw materials into products. All manufacturing costs must\nbe a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The"),
#  Document(metadata={'page': 21, 'type': 'text'}, page_content="be a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The\nresul'ng unit costs are used for inventory valua7on on the balance sheet and for the\ncalcula'on of the cost of goods sold on the income statement.\nMANUFACTURING COST\nFULL TOTAL COST\nABC COST\nPRIME COST\nTHROUGHPUT COST"),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_0'}, page_content='[Image: page_21_img_0]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_1'}, page_content='[Image: page_21_img_1]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_2'}, page_content='[Image: page_21_img_2]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_3'}, page_content='[Image: page_21_img_3]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_4'}, page_content='[Image: page_21_img_4]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_5'}, page_content='[Image: page_21_img_5]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_6'}, page_content='[Image: page_21_img_6]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_7'}, page_content='[Image: page_21_img_7]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_8'}, page_content='[Image: page_21_img_8]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_9'}, page_content='[Image: page_21_img_9]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_10'}, page_content='[Image: page_21_img_10]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_11'}, page_content='[Image: page_21_img_11]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_12'}, page_content='[Image: page_21_img_12]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_13'}, page_content='[Image: page_21_img_13]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_14'}, page_content='[Image: page_21_img_14]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_15'}, page_content='[Image: page_21_img_15]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_16'}, page_content='[Image: page_21_img_16]'),
#  Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_17'}, page_content='[Image: page_21_img_17]'),
#  Document(metadata={'page': 22, 'type': 'text'}, page_content='|  415 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST ACCOUNTING  \nMANAGERIAL COSTING  \nPRODUCT\nPRODUCT\nCUSTOMER\nDEPARTMENT\nSALE CHANNEL\nC\nO\nS\nT\nS\nDoes the speciﬁc cost \nitem pertain to the subset \nof costs that are meant to \nbe assigned to the cost \nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost  object and \nthe speciﬁc cost item here \nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\n   xxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\n      xxx.xxx'),
#  Document(metadata={'page': 22, 'type': 'text'}, page_content='NO\nASSET\n+ Sales\n   xxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\n      xxx.xxx\n- Other cost object’s costs\nxxx.xxx\n= Cost object margin\n      xxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\n      xxx.xxx\nYES\nAre the condi@on for \nmatching veriﬁed?\nWithin financial accounting we essentially have a single\ncost object (the “product”, typical or atypical, produced\nby the enterprise) and a single cost rule (called\n“absorption costing”)'),
#  Document(metadata={'page': 22, 'type': 'text'}, page_content="by the enterprise) and a single cost rule (called\n“absorption costing”)\nFor managerial cos'ng requirements we have, on the other hand,\nthe need to calculate the cost of several diﬀerent objects (several\nvery diﬀerent en''es) and apply several cost rules in order to\nobtain the relevant informa'on with respect to the decisions to\nbe taken\nCOST OBJECTS AND COST RULES"),
#  Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_0'}, page_content='[Image: page_22_img_0]'),
#  Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_1'}, page_content='[Image: page_22_img_1]'),
#  Document(metadata={'page': 23, 'type': 'text'}, page_content='|  416 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nABSORPTION COSTING'),
#  Document(metadata={'page': 23, 'type': 'image', 'image_id': 'page_23_img_0'}, page_content='[Image: page_23_img_0]'),
#  Document(metadata={'page': 23, 'type': 'image', 'image_id': 'page_23_img_1'}, page_content='[Image: page_23_img_1]'),
#  Document(metadata={'page': 24, 'type': 'text'}, page_content='|  417 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nC\nO\nS\nT\nS\nDoes\nthe\nspeciﬁc\ncost\nitem pertain to the subset\nof costs that are meant to\nbe assigned to the cost\nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost object and\nthe speciﬁc cost item here\nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\nxxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\nxxx.xxx\n- Other cost object’s costs\nxxx.xxx\n= Cost object margin\nxxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES'),
#  Document(metadata={'page': 24, 'type': 'text'}, page_content='xxx.xxx\n= Cost object margin\nxxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES\nAre the condi0on for \nmatching veriﬁed?\nVARIABLE COSTING'),
#  Document(metadata={'page': 24, 'type': 'image', 'image_id': 'page_24_img_0'}, page_content='[Image: page_24_img_0]'),
#  Document(metadata={'page': 25, 'type': 'text'}, page_content='|  418 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nVARIABLE COSTING\nRaw Material are used\nand\nconverted\nin\nFinished Products using\nDirect Labour and other\nManufacturing Resourcs\nProducts obtained are\nput into storage\nProducts obtained are\nsold to costumer\nRAW MATERIALS\nWORK IN PROCESS\nFINISHED PRODUCT\nCOST OF GOODS SOLD\nVariable Manufacturing Costs are incurred\nVariable Selling Costs are incurred'),
#  Document(metadata={'page': 25, 'type': 'image', 'image_id': 'page_25_img_0'}, page_content='[Image: page_25_img_0]'),
#  Document(metadata={'page': 26, 'type': 'text'}, page_content='|  419 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nC\nO\nS\nT\nS\nMORE PRECISELY \nDoes\nthe\nspeciﬁc\ncost\nitem pertain to the subset\nof costs that are meant to\nbe assigned to the cost\nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost object and\nthe speciﬁc cost item here\nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\nxxx.xxx\n- COGS (@ manufacturing variable) \nxxx.xxx\n= Manufacturing Variable Margin\nxxx.xxx\n- Selling variable costs\nxxx.xxx\n= Contribution Margin\nxxx.xxx\n- Fixed Costs'),
#  Document(metadata={'page': 26, 'type': 'text'}, page_content='xxx.xxx\n- Selling variable costs\nxxx.xxx\n= Contribution Margin\nxxx.xxx\n- Fixed Costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES\nAre the condi0on for \nmatching veriﬁed?\nWORK IN PROCESS\nFINISHED PRODUCT\nVariable Costs\nFixed Costs\nVariable Manufacturing Costs\nVariable Selling Costs\nWORK IN PROCESS\nFINISHED PRODUCT'),
#  Document(metadata={'page': 26, 'type': 'image', 'image_id': 'page_26_img_0'}, page_content='[Image: page_26_img_0]'),
#  Document(metadata={'page': 27, 'type': 'text'}, page_content='|  420 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COST AND JOB ORDER COST'),
#  Document(metadata={'page': 27, 'type': 'image', 'image_id': 'page_27_img_0'}, page_content='[Image: page_27_img_0]'),
#  Document(metadata={'page': 27, 'type': 'image', 'image_id': 'page_27_img_1'}, page_content='[Image: page_27_img_1]'),
#  Document(metadata={'page': 28, 'type': 'text'}, page_content='|  421 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT MATERIALS\nDIRECT LABOR\nMANUFACTURING \nOVERHEAD\nWORK IN PROCESS \nINVENTORY\nFINISHED GOODS\nINVENTORY\nCOST OF GOODS\nSOLD\nJOB COSTING SYSTEM\nJob costing is a costing system that accumulates costs and assigns them to speciﬁc jobs, customers, projects, or\ncontracts. The basic supporting document (usually in electronic form) in a job costing system is the job cost sheet.'),
#  Document(metadata={'page': 28, 'type': 'text'}, page_content='It records and summarizes the costs of direct materials, direct labor, and factory overhead for a particular job.\nA job costing system is used by companies that produce unique products or jobs. Examples of companies that use\njob costing systems include Boeing (airplanes), Lockheed Martin (advanced technology systems), and Deloitte &\nTouche (accounting).'),
#  Document(metadata={'page': 28, 'type': 'image', 'image_id': 'page_28_img_0'}, page_content='[Image: page_28_img_0]'),
#  Document(metadata={'page': 29, 'type': 'text'}, page_content='|  422 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#  Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_0'}, page_content='[Image: page_29_img_0]'),
#  Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_1'}, page_content='[Image: page_29_img_1]'),
#  Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_2'}, page_content='[Image: page_29_img_2]'),
#  Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_3'}, page_content='[Image: page_29_img_3]'),
#  Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_4'}, page_content='[Image: page_29_img_4]'),
#  Document(metadata={'page': 30, 'type': 'text'}, page_content='|  423 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#  Document(metadata={'page': 30, 'type': 'image', 'image_id': 'page_30_img_0'}, page_content='[Image: page_30_img_0]'),
#  Document(metadata={'page': 30, 'type': 'image', 'image_id': 'page_30_img_1'}, page_content='[Image: page_30_img_1]'),
#  Document(metadata={'page': 31, 'type': 'text'}, page_content='|  424 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT LABOR\nTRACED\nTRACED\nMANUFACTURING OVERHEAD\nALLOCATED\nOUTWORK\nTRACED\nCOST OF GOODS SOLD\nFINISHED PRODUCT\nCost of\ncompleted\nwork\nASSETS\nWORK IN PROCESS\nFLOW OF COSTS IN JOB COST SYSTEM\nRAW MATERIALS'),
#  Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_0'}, page_content='[Image: page_31_img_0]'),
#  Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_1'}, page_content='[Image: page_31_img_1]'),
#  Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_2'}, page_content='[Image: page_31_img_2]'),
#  Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_3'}, page_content='[Image: page_31_img_3]'),
#  Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_4'}, page_content='[Image: page_31_img_4]'),
#  Document(metadata={'page': 32, 'type': 'text'}, page_content='|  425 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#  Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_0'}, page_content='[Image: page_32_img_0]'),
#  Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_1'}, page_content='[Image: page_32_img_1]'),
#  Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_2'}, page_content='[Image: page_32_img_2]'),
#  Document(metadata={'page': 33, 'type': 'text'}, page_content='|  426 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nRAW MATERIALS\nOUTWORK\nSUPPLIES WITH \nIINSTALLATION\nDIRECT LABOR\nPHYSICAL SPACES\nUTILITY COSTS\nTRAVEL COSTS\nOTHER COSTS\nANCILLARY \nSERVICES\nBUILDING\nSHARED \nEQUIPMENT\nPROCUREMENT\nINBOUND \nLOGISTIC\nSTORAGE\nSALES\nENGENEERING\nCARPENTRY\nSHEET METAL\nELEMETS\nASSEMBLY\nREAL LIFE EXAMPLE\nINCOME STATEMENT'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_0'}, page_content='[Image: page_33_img_0]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_1'}, page_content='[Image: page_33_img_1]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_2'}, page_content='[Image: page_33_img_2]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_3'}, page_content='[Image: page_33_img_3]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_4'}, page_content='[Image: page_33_img_4]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_5'}, page_content='[Image: page_33_img_5]'),
#  Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_6'}, page_content='[Image: page_33_img_6]'),
#  Document(metadata={'page': 34, 'type': 'text'}, page_content='|  427 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFLOW OF DOCUMENTS'),
#  Document(metadata={'page': 34, 'type': 'image', 'image_id': 'page_34_img_0'}, page_content='[Image: page_34_img_0]'),
#  Document(metadata={'page': 34, 'type': 'image', 'image_id': 'page_34_img_1'}, page_content='[Image: page_34_img_1]'),
#  Document(metadata={'page': 35, 'type': 'text'}, page_content='|  428 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT MATERIALS\nDIRECT LABOR\nMANUFACTURING \nOVERHEAD\nWORK IN PROCESS\nSTAGE  # 2\nINVENTORY\nFINISHED GOODS\nINVENTORY\nCOST OF GOODS\nSOLD\nWORK IN PROCESS\nSTAGE  # 1\nINVENTORY\nWORK IN PROCESS\nSTAGE  # 3\nINVENTORY\nPROCESS COSTING SYSTEM\nProcess costing is a product costing system that accumulates costs according to processes or departments and'),
#  Document(metadata={'page': 35, 'type': 'text'}, page_content='assigns them to a large number of nearly identical products. A process costing system is used by companies that\nemploys a standardized production process to manufacture homogeneous products . Examples of companies that\nuse process costing include Chevron Corporation (petroleum products), the Wrigley Company (chewing gum),\nand Pittsburgh Paints (paint).\nDEPARTMENT\n“A”\nDEPARTMENT\n“B”\nDEPARTMENT\n“C”'),
#  Document(metadata={'page': 35, 'type': 'image', 'image_id': 'page_35_img_0'}, page_content='[Image: page_35_img_0]'),
#  Document(metadata={'page': 36, 'type': 'text'}, page_content='|  429 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COSTING SYSTEM'),
#  Document(metadata={'page': 36, 'type': 'image', 'image_id': 'page_36_img_0'}, page_content='[Image: page_36_img_0]'),
#  Document(metadata={'page': 36, 'type': 'image', 'image_id': 'page_36_img_1'}, page_content='[Image: page_36_img_1]'),
#  Document(metadata={'page': 37, 'type': 'text'}, page_content='|  430 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COSTING SYSTEM'),
#  Document(metadata={'page': 37, 'type': 'image', 'image_id': 'page_37_img_0'}, page_content='[Image: page_37_img_0]'),
#  Document(metadata={'page': 37, 'type': 'image', 'image_id': 'page_37_img_1'}, page_content='[Image: page_37_img_1]'),
#  Document(metadata={'page': 38, 'type': 'text'}, page_content='|  431 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFLOW OF COSTS IN PROCESS COST SYSTEM\nDIRECT LABOR\nMANUFACTURING OVERHEAD\nCOST OF GOODS SOLD\nFINISHED\nPRODUCT \nFINISHED PRODUCT\nCosts\ntransferred\nout to\nCosts\ntransferred\nout to\nCost of\ncompleted\nwork\nTRACED\nTRACED\nALLOCATED\nASSETS\nBLENDING STATION\nWORK IN PROCESS\nFILLING STATION\nWORK IN PROCESS\nLABELING  STATION\nWORK IN PROCESS\nRAW MATERIALS'),
#  Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_0'}, page_content='[Image: page_38_img_0]'),
#  Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_1'}, page_content='[Image: page_38_img_1]'),
#  Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_2'}, page_content='[Image: page_38_img_2]'),
#  Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_3'}, page_content='[Image: page_38_img_3]'),
#  Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_4'}, page_content='[Image: page_38_img_4]'),
#  Document(metadata={'page': 39, 'type': 'text'}, page_content='|  432 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB ORDER VERSUS PROCESS COST SYSTEMS'),
#  Document(metadata={'page': 39, 'type': 'image', 'image_id': 'page_39_img_0'}, page_content='[Image: page_39_img_0]'),
#  Document(metadata={'page': 39, 'type': 'image', 'image_id': 'page_39_img_1'}, page_content='[Image: page_39_img_1]'),
#  Document(metadata={'page': 40, 'type': 'text'}, page_content='|  433 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFINANCIAL ACCOUNTING  \nMANAGERIAL ACCOUNTING  \n§\nReports to those outside the \norganiza0on:\nOwners\nCreditors\nTax Authori0es\nRegulators\n§\nEmphasizes ﬁnancial consequence \nof past ac0vi0es\n§\nEmphasizes precision\n§\nEmphasizes companywide reports \n(focus on the whole)\n§\nMust follow GAAP/IFRS\n§\nMandatory for external reports.\n§\nReports to manager inside the \norganiza0on for\nPlanning\nControlling\n§\nEmphasizes decisions aﬀec0ng the'),
#  Document(metadata={'page': 40, 'type': 'text'}, page_content='organiza0on for\nPlanning\nControlling\n§\nEmphasizes decisions aﬀec0ng the \nfuture\n§\nEmphasizes ,meliness\n§\nEmphasizes segment reports (focus \non parts)\n§\nNeed not follow GAAP/IFRS\n§\nNot mandatory\nFINANCIAL ACCOUNTING VS. MANAGERIAL ACCOUNTING\nSOURCE: Adapted from Garrison, Noreen, Brewer,  “Managerial Accounting”, 16th Edition\n“suppor0ng documents” are normally needed \n(receipts, invoices, proofs of payment, etc.)'),
#  Document(metadata={'page': 40, 'type': 'image', 'image_id': 'page_40_img_0'}, page_content='[Image: page_40_img_0]'),
#  Document(metadata={'page': 41, 'type': 'text'}, page_content='|  434 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOSTS\nAll resources that are sacriﬁced or\nforgone in order to achieve a\nspeciﬁc objective.\nOPPORTUNITY COSTS \nForgone beneﬁts that could have been realized for the \nbest forgone alternative use of an actual resource\nEXPENSES\nCosts of assets consumed, or services used in the \nprocess of earning revenue. \nSOME BASIC DEFINITIONS'),
#  Document(metadata={'page': 41, 'type': 'image', 'image_id': 'page_41_img_0'}, page_content='[Image: page_41_img_0]'),
#  Document(metadata={'page': 42, 'type': 'text'}, page_content='|  435 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nINPUT MEASUREMENT BASE\nACTUAL COSTING SYSTEM\nDIRECT COST\nNORMAL COSTING SYSTEM\nSTANDARD COSTING SYSTEM\nINDIRECT COST\nActual\nActual\nActual\nStandard\nStandard\nStandard'),
#  Document(metadata={'page': 42, 'type': 'image', 'image_id': 'page_42_img_0'}, page_content='[Image: page_42_img_0]'),
#  Document(metadata={'page': 43, 'type': 'text'}, page_content='|  436 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nThe most accurate alloca0on can be made only when total overhead cost is known—and that is not un0l the\nend of the period. But managers cannot wait that long for product cost informa0on. So the predetermined\nmanufacturing overhead rate is calculated before the period begins. Companies use this predetermined rate\nto allocate es0mated overhead cost to individual jobs. The predetermined manufacturingoverhead rate is'),
#  Document(metadata={'page': 43, 'type': 'text'}, page_content='based on two factors:\n§ Total es0mated manufacturing overhead costs for the period (in Smart Touch’s case, one year)\n§ Total es0mated quan0ty of the manufacturing overhead alloca0on base\nThe key to alloca0ng (assigning) indirect manufacturing costs to jobs is to iden0fy a workable manufacturing\noverhead alloca0on base. The alloca0on base is a common denominator that links overhead costs to the'),
#  Document(metadata={'page': 43, 'type': 'text'}, page_content='products. Ideally, the alloca0on base is the primary cost driver of manufacturing overhead—that is, the\nmore “alloca0on base,” the more overhead costs and vice-versa. As the phrase implies, a cost driver is the\nprimary factor that causes (drives) a cost. Tradi0onally, manufacturing companies have used the following as\ncost drivers (alloca0on bases):\n• Direct labor hours (for labor-intensive produc0on environments)\n• Direct labor cost (for labor-intensive produc0on environments)'),
#  Document(metadata={'page': 43, 'type': 'text'}, page_content='• Direct labor cost (for labor-intensive produc0on environments)\n• Machine hours (for machine-intensive produc0on environments)\nPREDETERMINED MANUFACTURING OVERHEAD RATE'),
#  Document(metadata={'page': 43, 'type': 'image', 'image_id': 'page_43_img_0'}, page_content='[Image: page_43_img_0]'),
#  Document(metadata={'page': 43, 'type': 'image', 'image_id': 'page_43_img_1'}, page_content='[Image: page_43_img_1]'),
#  Document(metadata={'page': 44, 'type': 'text'}, page_content='|  437 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq In financial accounting, the typical cost objects are finished and semi-finished\nproducts. These “entities” are tangible resources with an economic value that\nare controllable by the company that produces them and, therefore, can be\nfound in the financial statements as assets. This means that the costs that are\nattributable to the products (both finished and semi-finished) can also be'),
#  Document(metadata={'page': 44, 'type': 'text'}, page_content='attributable to the products (both finished and semi-finished) can also be\n“inventoried” (that is to say their “amount” can be added to a stock inventory\nand therefore subtracted from the formation of the economic result) if the\nunits to which they are allocated are still present in the inventory.\nq Cost\nobjects\nused\nin\nmanagerial\ncosting\ndo\nnot\nalways\nhave\nthese\ncharacteristics. There are, for example, cost objects such as activities'),
#  Document(metadata={'page': 44, 'type': 'text'}, page_content='do\nnot\nalways\nhave\nthese\ncharacteristics. There are, for example, cost objects such as activities\nperformed, or customers served, or sales channels used, or others that cannot\nbe reported as assets on the balance sheet. For this reason, for the purposes\nof the reasoning that we are about to do, we must begin by distinguishing the\nset of costs that can be attributed to a specific cost object from its possible\nsubset that contains “inventoriable costs” (that is to say costs that can be'),
#  Document(metadata={'page': 44, 'type': 'text'}, page_content='subset that contains “inventoriable costs” (that is to say costs that can be\nactually “offset” by a corresponding increase in the value of inventories ).\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#  Document(metadata={'page': 44, 'type': 'image', 'image_id': 'page_44_img_0'}, page_content='[Image: page_44_img_0]'),
#  Document(metadata={'page': 45, 'type': 'text'}, page_content='|  438 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq The “cost collec(on and alloca(on process” can be viewed as a set of cost\naccumula(on and alloca(on steps. We can think of the accumula(on phases\nas the arrival and departure points of the process (but also the intermediate\nstopping points) while the alloca(on phases represent the moments of\nmovement from a speciﬁc point to the next one.\nq The wording "cost accumula(on" iden(ﬁes the ac(vi(es of collec(ng a set of'),
#  Document(metadata={'page': 45, 'type': 'text'}, page_content='q The wording "cost accumula(on" iden(ﬁes the ac(vi(es of collec(ng a set of\ncosts that refer to the same cost object. This means that normally the “cost” of\na cost object is a compound cost, consis(ng of the sum of several elementary\ncosts.\nq The wording "cost alloca(on" iden(ﬁes, instead, the transfer of a cost value\npreviously recorded in rela(on to a cost object, to a subsequent cost object.\nq As you certainly know, ﬂow chart is a picture of the separate steps of a process'),
#  Document(metadata={'page': 45, 'type': 'text'}, page_content='q As you certainly know, ﬂow chart is a picture of the separate steps of a process\nin sequen(al order. Well, the “cost collec(on and alloca(on process” can be\neﬀec(vely represented thanks to the employment of a ﬂow chart in which the\nstages are the moments of cost accumula(on, and the vectors are the phases\nof cost alloca(on.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#  Document(metadata={'page': 45, 'type': 'image', 'image_id': 'page_45_img_0'}, page_content='[Image: page_45_img_0]'),
#  Document(metadata={'page': 46, 'type': 'text'}, page_content='|  439 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq In order to be truly eﬀec(ve, a process of accumula(on and alloca(on of costs\nmust portray as realis(cally as possible the ﬂow of ac(vi(es that make up the\nproduc(on process. In fact, it is these ac(vi(es, and the ways in which they are\ncarried out, that determine the transfer of the value contained in the resources\nﬁrst to the WIP and then to the ﬁnished products and from these eventually to\nthe customers.'),
#  Document(metadata={'page': 46, 'type': 'text'}, page_content='ﬁrst to the WIP and then to the ﬁnished products and from these eventually to\nthe customers.\nq Clearly, the ac(vi(es that deﬁne produc(on processes take a diﬀerent form\ndepending\non\nthe\ntechnology\nemployed\nand\nthe\nproduc(on\nprocess\nundertaken. The process of cost alloca(on must, therefore, respect these\nspeciﬁci(es and cannot take place in a standardized way, i.e., using using the\nsame structure regardless of the speciﬁc process developed.'),
#  Document(metadata={'page': 46, 'type': 'text'}, page_content='same structure regardless of the speciﬁc process developed.\nq They exist but of the general archetypes that can be used like bases of\nreference in order to dis(nguish two various modali(es to conﬁgure the\nproduc(ve ac(vi(es and therefore the ﬂow of accumula(on and aaribu(on of\nthe costs. These are: the “job cos(ng system”, used by companies that produce\nunique products or jobs, and “process cos(ng system” used instead by\ncompanies that employs a standardized produc(on process to manufacture'),
#  Document(metadata={'page': 46, 'type': 'text'}, page_content='companies that employs a standardized produc(on process to manufacture\nhomogeneous products.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#  Document(metadata={'page': 46, 'type': 'image', 'image_id': 'page_46_img_0'}, page_content='[Image: page_46_img_0]'),
#  Document(metadata={'page': 47, 'type': 'text'}, page_content='|  440 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq There are three methods managers and accountants can use to calculate\nproduct unit cost:\n§\nActual costing method,\n§\nNormal costing method, or\n§\nStandard costing method.\nq The actual costing method uses the actual costs of direct materials, direct\nlabor, and overhead when they become known to calculate the product unit\ncost. This means, many times, waiting until the end of the period when all the'),
#  Document(metadata={'page': 47, 'type': 'text'}, page_content='cost. This means, many times, waiting until the end of the period when all the\ncost data are available. For most companies, this is not practical.\nq The normal costing method combines the easy-to-track actual direct costs of\nmaterials and labour with estimated overhead costs to determine a product\nunit cost. The use of this costing method is widespread, since many overhead\nbills, such as utility bills, are not received until after products or services are'),
#  Document(metadata={'page': 47, 'type': 'text'}, page_content='bills, such as utility bills, are not received until after products or services are\nproduced and sold. For this reason, normal costing system that uses actual\ncosts for direct materials, direct labour and other direct costs and applies\nindirect costs using a predetermined overhead cost rate.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#  Document(metadata={'page': 47, 'type': 'image', 'image_id': 'page_47_img_0'}, page_content='[Image: page_47_img_0]'),
#  Document(metadata={'page': 48, 'type': 'text'}, page_content='|  441 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq To compute the predetermined overhead rate, four steps are needed:\n1. Es(mate total overhead costs for the opera(ng period, usually a year.\n2. Select the most appropriate alloca(on base (i.e. the basis that best\nreﬂects the cause-eﬀect rela(onship that links indirect costs to the\nchosen cost object)\n3. Es(mate the total amount of the chosen alloca(on base for the opera(ng \nperiod.'),
#  Document(metadata={'page': 48, 'type': 'text'}, page_content='3. Es(mate the total amount of the chosen alloca(on base for the opera(ng \nperiod.\n4. Divide the es(mated  total overhead costs by the es(mated amount of \nthe chosen alloca(on base to obtain the predetermined overhead rate.\nq The standard cos(ng method uses es(mated or standard costs of direct\nmaterials, direct labour, and overhead to calculate the product unit cost. This\nmethod is used because managers some(mes need product cost informa(on'),
#  Document(metadata={'page': 48, 'type': 'text'}, page_content='method is used because managers some(mes need product cost informa(on\nbefore the accoun(ng period begins so that they can control the cost of\nopera(ng ac(vi(es or price a proposed product for a customer. In such\nsitua(ons, product unit costs must be es(mated, and the standard cos(ng\nmethod can be helpful. Moreover, standard cos(ng is very useful in\nperformance management and evalua(on because a manager can compare\nactual and standard costs to compute the variances. In such a way it becomes a'),
#  Document(metadata={'page': 48, 'type': 'text'}, page_content='actual and standard costs to compute the variances. In such a way it becomes a\ntool for exercise a form of steering control and can be used for learning.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#  Document(metadata={'page': 48, 'type': 'image', 'image_id': 'page_48_img_0'}, page_content='[Image: page_48_img_0]')]

# %%
# Create unified FAISS vector store with CLIP embeddings
embeddings_array = np.array(all_embeddings)
embeddings_array
# Out:
# array([[-0.04622868,  0.01753438,  0.03629856, ..., -0.08006593,
#         -0.01380648, -0.00609296],
#        [-0.02515623, -0.02274406,  0.05144298, ...,  0.01638889,
#          0.01698227, -0.05855679],
#        [-0.0089438 ,  0.00232195, -0.00363326, ...,  0.06655418,
#         -0.0269383 , -0.01064131],
#        ...,
#        [ 0.0050875 ,  0.01034724, -0.00103213, ...,  0.00999359,
#          0.02369087,  0.00190299],
#        [-0.00482922,  0.00452271, -0.01624018, ..., -0.05643078,
#          0.02530663,  0.00100464],
#        [-0.02515623, -0.02274406,  0.05144298, ...,  0.01638889,
#          0.01698227, -0.05855679]], dtype=float32)

# %%
(all_docs,embeddings_array)
# Out:
# ([Document(metadata={'page': 0, 'type': 'text'}, page_content='|  393 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST AND REVENUE ANALYSIS\nHow to produce par-al proﬁtability informa-on'),
#   Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_0'}, page_content='[Image: page_0_img_0]'),
#   Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_1'}, page_content='[Image: page_0_img_1]'),
#   Document(metadata={'page': 1, 'type': 'text'}, page_content='|  394 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\nOPHYSICAL\nIPHYSICAL\nOREVENUES\nIEXPENSES\na) Partial \nb) Total \na) Partial\nb) Total'),
#   Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_0'}, page_content='[Image: page_1_img_0]'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='|  395 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\na) Partial \x01\nb) Total \x02\na) Partial \x02\nb) Total \x01\nJUST THE OPPOSITE'),
#   Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_0'}, page_content='[Image: page_2_img_0]'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='|  396 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales revenues\n265.780\n€        \n100,00%\n- Cost of goods sold (@manufacturing variable cost)\n85.330\n-€          \n-32,11%\n= Manufacturing variable margin\n180.450\n€        \n67,89%\n- Sales variable costs\n24.550\n-€          \n-9,24%\n= Contribution margin\n155.900\n€        \n58,66%\n- Fixed costs (excluding depreciation and amortization costs)\n83.009\n-€          \n-31,23%\n= EBITDA\n72.891\n€          \n27,43%'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='83.009\n-€          \n-31,23%\n= EBITDA\n72.891\n€          \n27,43%\n- Depreciation and amortization costs\n38.126\n-€          \n-14,34%\n= EBIT\n34.765\n€          \n13,08%\n- Interst expenses\n12.500\n-€          \n-4,70%\n= EBT\n22.265\n€          \n8,38%\n- Income taxes\n6.680\n-€            \n-2,51%\n= EAT\n15.586\n€          \n5,86%\nDIFFERENT POSSIBLE PROFIT MARGINS'),
#   Document(metadata={'page': 3, 'type': 'image', 'image_id': 'page_3_img_0'}, page_content='[Image: page_3_img_0]'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='|  397 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales Revenues\n– Cost of Goods Sold\n= Gross Margin\n– S,G&A Expenses\n= EBIT\n– Interest Expenses\n= EBT\nBoard of \nDirector\nR&D\nOperations\nPurchasing \nProduction\nMarketing & \nSales\nMarketing\nSales\nAccounting & \nFinance\nAccounting\nFinance\nHR\nSOME IMPORTANT RELATIONSHIPS'),
#   Document(metadata={'page': 4, 'type': 'image', 'image_id': 'page_4_img_0'}, page_content='[Image: page_4_img_0]'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='|  398 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nProduct "A"\n657.235\n€        \nCustomer "X"\n432.001\n€        \nResponsability center "1"\n2.433.015\n€     \nProduct "B"\n546.763\n€        \nCustomer "Y"\n367.455\n€        \nResponsability center "2"\n1.774.550\n€     \nProduct "C"\n432.267\n€        \nCustomer "W"\n312.826\n€        \nResponsability center "3"\n64.520\n-€          \n……...............\n…........................\n……...............\n…........................\n……...............'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='…........................\n……...............\n…........................\n……...............\n…........................\nProduct "N"\n138.758\n-€        \nCustomer "K"\n25.789\n-€          \nResponsability center "12"\n835.519\n-€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nCOST ANALYSIS\nDIFFERENT SEGMENT\nFINANCIAL ACCOUNTING\nTotal Financial Productivity \nMANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='MANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity \nFinancial and \nnonfinancial information \nFROM TOTAL TO PARTIAL FINANCIAL PRODUCTIVITY\n+ Operating revenues\n4.207.565\n€     \n- Operating costs\n3.705.816\n-€     \n= Operating profit\n501.749\n€'),
#   Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_0'}, page_content='[Image: page_5_img_0]'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='|  399 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST OBJECTS\nGli oggetti di riferimento\n“External”\nCustomers or clusters of Customers\nDistribution Channels\nGeographical Areas\nSuppliers\n“Internal”\nResources (Means of Production)\nResponsibility Centers (Departments)\nActivities or Processes\nProjects\nWIPs\nProducts or Product Lines\nThese\ncost\nobjects\nare\nthe\nmost\ninnovative: they denote the adoption of a\nmore modern management control. The\nfocus is on the outside world.'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='more modern management control. The\nfocus is on the outside world.\nThose who adopt this perspective seek to\nobtain\nthe\ninformation\nnecessary\nto\nmanage\nmarket\ncompetition\nmore\neffectively\nDIFFERENT COST OBJECTS'),
#   Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_0'}, page_content='[Image: page_6_img_0]'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='|  400 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\n+ Sales Revenues\n- Sales Commissions\n---------------------------------------------------\n= Net Revenues\n- Direct Materials\n-----------------------------------------------------\n= First Margin\n- Outsourced Work\n-----------------------------------------------------\n= Second Margin\n- Other Direct Costs\n- Direct Labor\n-----------------------------------------------------\n= Job Orders Direct Margin\nxxx\nxxx\n--------\n= xxx\n- xxx'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='= Job Orders Direct Margin\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB 1\nJOB 2\nJOB 3\n∑\n∑\n--------\n= ∑\n∑\n--------\n= ∑\n∑\n--------\n= ∑\n- ∑\n- ∑\n--------\n= ∑\nTotal\n- Manufacturing Overhead\n- Selling Overhead Expenses\n- Administrative Expenses\n- General Expenses\n------------------------------------------------------\n= Ebit\n- xxx\n- xxx\n- xxx\n- xxx\n--------\n= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB N\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nJOB …\nxxx\nxxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n--------\n= xxx\n- xxx\n- xxx\n--------\n= xxx\nA SEGMENT INCOME STATEMENT'),
#   Document(metadata={'page': 7, 'type': 'image', 'image_id': 'page_7_img_0'}, page_content='[Image: page_7_img_0]'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='|  401 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nWHY IT IS DIFFICULT TO COMPUTE….  \nPartial ﬁnancial productivity measure: \nRESOURCE\nCOST\nCOST OBJECT 1\nCOST OBJECT 2'),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_0'}, page_content='[Image: page_8_img_0]'),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_1'}, page_content='[Image: page_8_img_1]'),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_2'}, page_content='[Image: page_8_img_2]'),
#   Document(metadata={'page': 8, 'type': 'image', 'image_id': 'page_8_img_3'}, page_content='[Image: page_8_img_3]'),
#   Document(metadata={'page': 9, 'type': 'text'}, page_content='|  402 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nEFFICIENCY\n1. OPERATIONAL \nPRODUCTIVITY\n2. FINANCIAL \nPRODUCTIVITY\na) Partial \x01\nb) Total \x02\na) Partial \x02\nb) Total \x01\nWHY IT IS DIFFICULT TO COMPUTE….'),
#   Document(metadata={'page': 9, 'type': 'image', 'image_id': 'page_9_img_0'}, page_content='[Image: page_9_img_0]'),
#   Document(metadata={'page': 10, 'type': 'text'}, page_content='|  403 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nProduct "A"\n657.235\n€        \nCustomer "X"\n432.001\n€        \nResponsability center "1"\n2.433.015\n€     \nProduct "B"\n546.763\n€        \nCustomer "Y"\n367.455\n€        \nResponsability center "2"\n1.774.550\n€     \nProduct "C"\n432.267\n€        \nCustomer "W"\n312.826\n€        \nResponsability center "3"\n64.520\n-€          \n……...............\n…........................\n……...............\n…........................\n……...............'),
#   Document(metadata={'page': 10, 'type': 'text'}, page_content='…........................\n……...............\n…........................\n……...............\n…........................\nProduct "N"\n138.758\n-€        \nCustomer "K"\n25.789\n-€          \nResponsability center "12"\n835.519\n-€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nOperating profit\n501.749\n€        \nCOST ANALYSIS\nDIFFERENT SEGMENT\nFINANCIAL ACCOUNTING\nTotal Financial Productivity \nMANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity'),
#   Document(metadata={'page': 10, 'type': 'text'}, page_content='MANAGERIAL ACCOUNTING and\nMANAGERIAL COSTING\nPartial Financial Productivity \nFinancial and \nnonﬁnancial information \nFROM TOTAL TO PARTIAL FINANCIAL PRODUCTIVITY\n+ Operating revenues\n4.207.565\n€     \n- Operating costs\n3.705.816\n-€     \n= Operating profit\n501.749\n€'),
#   Document(metadata={'page': 10, 'type': 'image', 'image_id': 'page_10_img_0'}, page_content='[Image: page_10_img_0]'),
#   Document(metadata={'page': 11, 'type': 'text'}, page_content='|  404 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST COLLECTION SYSTEMS \nCost accumulation is the collection of cost data in some organized way by means of\nan accounting system.\nCost collection systems typically accounts for costs in two broad stages:\n1. they initially accumulates costs classifying them “by nature”: that is to say\ninto categories that remind us the type of resources purchased or consumed'),
#   Document(metadata={'page': 11, 'type': 'text'}, page_content='into categories that remind us the type of resources purchased or consumed\n(e.g., raw materials, depreciation, transports costs, rent expenses, wages and\nsalaries, etc.). Later this criterion is combined with other two that focus their\nattention on cost behavior (ﬁxed and variable costs) or on the robustness of\nthe relation that link a cost to a speciﬁc cost objects (direct and indirect costs) .\n2. They then assign these costs to cost objects.\nCOST\nACCUMULATIONS\nCOST\nASSIGNMENT'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_0'}, page_content='[Image: page_11_img_0]'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_1'}, page_content='[Image: page_11_img_1]'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_2'}, page_content='[Image: page_11_img_2]'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_3'}, page_content='[Image: page_11_img_3]'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_4'}, page_content='[Image: page_11_img_4]'),
#   Document(metadata={'page': 11, 'type': 'image', 'image_id': 'page_11_img_5'}, page_content='[Image: page_11_img_5]'),
#   Document(metadata={'page': 12, 'type': 'text'}, page_content='|  405 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST ANALYSIS\nThe concrete implementa.on of a proper cost analysis requires to make some\nbasic decisions about the following issues:\n§\nCost Object\n§\nPeriodicity of the analysis (one .me “had hoc” versus systema.c)\n§\nPor.on of the cost base that is to be assigned to the cost object: selec.on\nof the “cost rule” that is to say of the evalua.on criterion – in terms of cost\n– for the cost object)\n§'),
#   Document(metadata={'page': 12, 'type': 'text'}, page_content='– for the cost object)\n§\nStructure of the cost ﬂow: selec.on of the proper accumula.on’s method\n§\nInput measurement base'),
#   Document(metadata={'page': 12, 'type': 'image', 'image_id': 'page_12_img_0'}, page_content='[Image: page_12_img_0]'),
#   Document(metadata={'page': 13, 'type': 'text'}, page_content='|  406 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST OBJECTS\nGli oggetti di riferimento\n“External”\nCustomers or clusters of Customers\nDistribution Channels\nGeographical Areas\nSuppliers\n“Internal”\nResources (Means of Production)\nResponsibility Centers (Departments)\nActivities or Processes\nProjects\nWIPs\nProducts or Product Lines\nThese\ncost\nobjects\nare\nthe\nmost\ninnovative: they denote the adoption of a\nmore modern management control. The\nfocus is on the outside world.'),
#   Document(metadata={'page': 13, 'type': 'text'}, page_content='more modern management control. The\nfocus is on the outside world.\nThose who adopt this perspective seek to\nobtain\nthe\ninformation\nnecessary\nto\nmanage\nmarket\ncompetition\nmore\neffectively\nDIFFERENT COST OBJECTS'),
#   Document(metadata={'page': 13, 'type': 'image', 'image_id': 'page_13_img_0'}, page_content='[Image: page_13_img_0]'),
#   Document(metadata={'page': 14, 'type': 'text'}, page_content='|  407 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nA RESOURCE AS A COST OBJECT\nlubrica(ng oil\ntyres\nmechanical parts\nbrakes\ndriving ac(vity\nrepairs and maintenance\ncasualty insurance\ngasoline\nO\nI\nhours of work performed\nPlease note: the cost of opera0ng a tractor is a compound cost consis,ng of the sum of many elementary costs. \nsome of these costs are incurred exclusively for the opera0on of the tractor (tyres deprecia0on) others, however,'),
#   Document(metadata={'page': 14, 'type': 'text'}, page_content='are also incurred for other reasons (the cost of personnel who, in addi0on to doing other things, drive the tractor).'),
#   Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_0'}, page_content='[Image: page_14_img_0]'),
#   Document(metadata={'page': 14, 'type': 'image', 'image_id': 'page_14_img_1'}, page_content='[Image: page_14_img_1]'),
#   Document(metadata={'page': 15, 'type': 'text'}, page_content='|  408 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nRELATION BETWEEN DIFFERENT COST OBJECTS\nTRACTOR\n(Resource)\nPHYTOSANITARY TREATMENTS\n(Ac,vity)\nGRAPE TRANSPORTATION \n(Activity)\nVINEYARD\n(Resource)\nGRAPE\n(WIP)\nSPRAYER\n(Resource)\nWINE\n(WIP)\nBOTTLE OF WINE\n(PRODUCT )'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_0'}, page_content='[Image: page_15_img_0]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_1'}, page_content='[Image: page_15_img_1]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_2'}, page_content='[Image: page_15_img_2]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_3'}, page_content='[Image: page_15_img_3]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_4'}, page_content='[Image: page_15_img_4]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_5'}, page_content='[Image: page_15_img_5]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_6'}, page_content='[Image: page_15_img_6]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_7'}, page_content='[Image: page_15_img_7]'),
#   Document(metadata={'page': 15, 'type': 'image', 'image_id': 'page_15_img_8'}, page_content='[Image: page_15_img_8]'),
#   Document(metadata={'page': 16, 'type': 'text'}, page_content='|  409 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nA VAN AS A RESPONSIBILITY CENTER\nlubrica0ng oil\ntyres\nmechanical parts\nbrakes\nrepairs and maintenance\ncasualty insurance\ngasoline\n€ \nbasic wage \ndearness allowance\nbonuses\nemployer’s contribu0on to \nemployees’ state insurance\nfringe beneﬁts\ncustom duty paid\ntransit insurance\ncost of goods \nloading and \nunloading charges\ncarriage paid'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_0'}, page_content='[Image: page_16_img_0]'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_1'}, page_content='[Image: page_16_img_1]'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_2'}, page_content='[Image: page_16_img_2]'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_3'}, page_content='[Image: page_16_img_3]'),
#   Document(metadata={'page': 16, 'type': 'image', 'image_id': 'page_16_img_4'}, page_content='[Image: page_16_img_4]'),
#   Document(metadata={'page': 17, 'type': 'text'}, page_content='|  410 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nVARIABLE COSTS\nFIXED COSTS\nUNITS\nTRANSACTIONS\nPRODUCTS\nCUSTOMERS\nCHANNELS\nPROJECTS\nRELATION BETWEEN DIFFERENT COST OBJECTS\nSUPPLIERS\nRESOURCES'),
#   Document(metadata={'page': 17, 'type': 'image', 'image_id': 'page_17_img_0'}, page_content='[Image: page_17_img_0]'),
#   Document(metadata={'page': 18, 'type': 'text'}, page_content='|  411 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST & REVENUES ANALYSIS\nA set of logic, criteria, methods\nand techniques for the\n² collection,\n² classiﬁcation,\n² aggregation and\n² attribution\nof costs and revenues\nSYSTEMATIC AND CONSTANT INFORMATION FLOWS\nPRODUCTION OF "AD HOC" INFORMATION\nIN RELATION TO SPECIFIC DECISION MAKING\nFinalità del calcolo dei cos. - 2\nCOST SYSTEMS\nFocused on cost-objects that are considered\nparticularly relevant for day-by-day decisions'),
#   Document(metadata={'page': 18, 'type': 'text'}, page_content='Focused on cost-objects that are considered\nparticularly relevant for day-by-day decisions\nand, therefore, that need constant monitoring\nONE-OFF COST ANALYSIS\nRelating to speciﬁc cost-objects, from time to\ntime different depending on the\ntype of\ndecision to be taken\nPERIODICITY OF THE ANALYSIS'),
#   Document(metadata={'page': 18, 'type': 'image', 'image_id': 'page_18_img_0'}, page_content='[Image: page_18_img_0]'),
#   Document(metadata={'page': 19, 'type': 'text'}, page_content='|  412 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDecision to be made:\nA. Things to do in Rome \nwhile visi(ng the city as a \ntourist for a ﬁve days \nperiod \nB. Things to do in Rome \nwhile spending a six \nmonths period in the city \nfor work\n§\nDiﬀerent possible hotel/B&B \naccommoda(ons\n§\nBest restaurants in town\n§\nUnderground (ckets and weekly \npass\n§\nBest Museum\n§\nExercise drills\n§\nApartments monthly rates \n§\nConvenient grocery stores \nnearby\n§'),
#   Document(metadata={'page': 19, 'type': 'text'}, page_content='§\nBest Museum\n§\nExercise drills\n§\nApartments monthly rates \n§\nConvenient grocery stores \nnearby\n§\nUsed cars prices, buses and train \nmonthly pass \n§\nPlaces to visit in the surrounding \narea\n§\nGym and swimming pool \nmemberships\nDIFFERENT DECISIONS , DIFFERENT SETS OF INFORMATIONS'),
#   Document(metadata={'page': 19, 'type': 'image', 'image_id': 'page_19_img_0'}, page_content='[Image: page_19_img_0]'),
#   Document(metadata={'page': 20, 'type': 'text'}, page_content='|  413 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIFFERENT FUNCTIONS, DIFFERENT DEMANDS\nSOURCE: Kaplan,  “One Cost System Isn’t Enough ”, Harvard Business Review, January - February 1988\nFunctions  \nFrequency  \nAllocation  \nScope of  \nNature of \nDegree of \n \n \n \nSystem  \nVariability  \nObjectivity \nInventory  \nMonthly or  \nAggregate  \nFactory  \nIrrelevant  \nHigh \nvaluation  \nquarterly  \n \ncosts \nOperational  \nDaily, by  \nNone  \nResponsibility  \nShort-term  \nHigh \ncontrol'),
#   Document(metadata={'page': 20, 'type': 'text'}, page_content='quarterly  \n \ncosts \nOperational  \nDaily, by  \nNone  \nResponsibility  \nShort-term  \nHigh \ncontrol  \nunit of work  \n \ncenter  \nvariable \naccomplished  \n \n \nand fixed \nProduct cost  \nAnnually and  \nExtensive, down  \nEntire organization \nAll variable \nLow \nmeasurement  \nat major change  \nto individual   \nincluding marketing \npoints \nproducts or \nand distribution, \n \nproduct lines \nengineering, service, \n \n \nand administration'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_0'}, page_content='[Image: page_20_img_0]'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_1'}, page_content='[Image: page_20_img_1]'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_2'}, page_content='[Image: page_20_img_2]'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_3'}, page_content='[Image: page_20_img_3]'),
#   Document(metadata={'page': 20, 'type': 'image', 'image_id': 'page_20_img_4'}, page_content='[Image: page_20_img_4]'),
#   Document(metadata={'page': 21, 'type': 'text'}, page_content="|  414 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIFFERENT VALUATION CRETERIA FOR A PRODUCT\nNET REALIZABLE VALUE\nThe es'mated selling price in the\nordinary course of business minus\nany cost to complete and to sell\nthe goods\nVARIABLE MANUFACTURING COST\nVARIABLE COST\nThe costs necessary to convert raw materials into products. All manufacturing costs must\nbe a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The"),
#   Document(metadata={'page': 21, 'type': 'text'}, page_content="be a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The\nresul'ng unit costs are used for inventory valua7on on the balance sheet and for the\ncalcula'on of the cost of goods sold on the income statement.\nMANUFACTURING COST\nFULL TOTAL COST\nABC COST\nPRIME COST\nTHROUGHPUT COST"),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_0'}, page_content='[Image: page_21_img_0]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_1'}, page_content='[Image: page_21_img_1]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_2'}, page_content='[Image: page_21_img_2]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_3'}, page_content='[Image: page_21_img_3]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_4'}, page_content='[Image: page_21_img_4]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_5'}, page_content='[Image: page_21_img_5]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_6'}, page_content='[Image: page_21_img_6]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_7'}, page_content='[Image: page_21_img_7]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_8'}, page_content='[Image: page_21_img_8]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_9'}, page_content='[Image: page_21_img_9]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_10'}, page_content='[Image: page_21_img_10]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_11'}, page_content='[Image: page_21_img_11]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_12'}, page_content='[Image: page_21_img_12]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_13'}, page_content='[Image: page_21_img_13]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_14'}, page_content='[Image: page_21_img_14]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_15'}, page_content='[Image: page_21_img_15]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_16'}, page_content='[Image: page_21_img_16]'),
#   Document(metadata={'page': 21, 'type': 'image', 'image_id': 'page_21_img_17'}, page_content='[Image: page_21_img_17]'),
#   Document(metadata={'page': 22, 'type': 'text'}, page_content='|  415 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOST ACCOUNTING  \nMANAGERIAL COSTING  \nPRODUCT\nPRODUCT\nCUSTOMER\nDEPARTMENT\nSALE CHANNEL\nC\nO\nS\nT\nS\nDoes the speciﬁc cost \nitem pertain to the subset \nof costs that are meant to \nbe assigned to the cost \nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost  object and \nthe speciﬁc cost item here \nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\n   xxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\n      xxx.xxx'),
#   Document(metadata={'page': 22, 'type': 'text'}, page_content='NO\nASSET\n+ Sales\n   xxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\n      xxx.xxx\n- Other cost object’s costs\nxxx.xxx\n= Cost object margin\n      xxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\n      xxx.xxx\nYES\nAre the condi@on for \nmatching veriﬁed?\nWithin financial accounting we essentially have a single\ncost object (the “product”, typical or atypical, produced\nby the enterprise) and a single cost rule (called\n“absorption costing”)'),
#   Document(metadata={'page': 22, 'type': 'text'}, page_content="by the enterprise) and a single cost rule (called\n“absorption costing”)\nFor managerial cos'ng requirements we have, on the other hand,\nthe need to calculate the cost of several diﬀerent objects (several\nvery diﬀerent en''es) and apply several cost rules in order to\nobtain the relevant informa'on with respect to the decisions to\nbe taken\nCOST OBJECTS AND COST RULES"),
#   Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_0'}, page_content='[Image: page_22_img_0]'),
#   Document(metadata={'page': 22, 'type': 'image', 'image_id': 'page_22_img_1'}, page_content='[Image: page_22_img_1]'),
#   Document(metadata={'page': 23, 'type': 'text'}, page_content='|  416 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nABSORPTION COSTING'),
#   Document(metadata={'page': 23, 'type': 'image', 'image_id': 'page_23_img_0'}, page_content='[Image: page_23_img_0]'),
#   Document(metadata={'page': 23, 'type': 'image', 'image_id': 'page_23_img_1'}, page_content='[Image: page_23_img_1]'),
#   Document(metadata={'page': 24, 'type': 'text'}, page_content='|  417 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nC\nO\nS\nT\nS\nDoes\nthe\nspeciﬁc\ncost\nitem pertain to the subset\nof costs that are meant to\nbe assigned to the cost\nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost object and\nthe speciﬁc cost item here\nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\nxxx.xxx\n- Cost from the use of the asset xxx.xxx\n= First margin\nxxx.xxx\n- Other cost object’s costs\nxxx.xxx\n= Cost object margin\nxxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES'),
#   Document(metadata={'page': 24, 'type': 'text'}, page_content='xxx.xxx\n= Cost object margin\nxxx.xxx\n- Other costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES\nAre the condi0on for \nmatching veriﬁed?\nVARIABLE COSTING'),
#   Document(metadata={'page': 24, 'type': 'image', 'image_id': 'page_24_img_0'}, page_content='[Image: page_24_img_0]'),
#   Document(metadata={'page': 25, 'type': 'text'}, page_content='|  418 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nVARIABLE COSTING\nRaw Material are used\nand\nconverted\nin\nFinished Products using\nDirect Labour and other\nManufacturing Resourcs\nProducts obtained are\nput into storage\nProducts obtained are\nsold to costumer\nRAW MATERIALS\nWORK IN PROCESS\nFINISHED PRODUCT\nCOST OF GOODS SOLD\nVariable Manufacturing Costs are incurred\nVariable Selling Costs are incurred'),
#   Document(metadata={'page': 25, 'type': 'image', 'image_id': 'page_25_img_0'}, page_content='[Image: page_25_img_0]'),
#   Document(metadata={'page': 26, 'type': 'text'}, page_content='|  419 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nC\nO\nS\nT\nS\nMORE PRECISELY \nDoes\nthe\nspeciﬁc\ncost\nitem pertain to the subset\nof costs that are meant to\nbe assigned to the cost\nobject?\nYES\nNO\nCOST OBJECT\nAre both the cost object and\nthe speciﬁc cost item here\nconsidered “inventoriable”?\nYES\nNO\nASSET\n+ Sales\nxxx.xxx\n- COGS (@ manufacturing variable) \nxxx.xxx\n= Manufacturing Variable Margin\nxxx.xxx\n- Selling variable costs\nxxx.xxx\n= Contribution Margin\nxxx.xxx\n- Fixed Costs'),
#   Document(metadata={'page': 26, 'type': 'text'}, page_content='xxx.xxx\n- Selling variable costs\nxxx.xxx\n= Contribution Margin\nxxx.xxx\n- Fixed Costs\nxxx.xxx\n= EBIT\nxxx.xxx\nYES\nAre the condi0on for \nmatching veriﬁed?\nWORK IN PROCESS\nFINISHED PRODUCT\nVariable Costs\nFixed Costs\nVariable Manufacturing Costs\nVariable Selling Costs\nWORK IN PROCESS\nFINISHED PRODUCT'),
#   Document(metadata={'page': 26, 'type': 'image', 'image_id': 'page_26_img_0'}, page_content='[Image: page_26_img_0]'),
#   Document(metadata={'page': 27, 'type': 'text'}, page_content='|  420 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COST AND JOB ORDER COST'),
#   Document(metadata={'page': 27, 'type': 'image', 'image_id': 'page_27_img_0'}, page_content='[Image: page_27_img_0]'),
#   Document(metadata={'page': 27, 'type': 'image', 'image_id': 'page_27_img_1'}, page_content='[Image: page_27_img_1]'),
#   Document(metadata={'page': 28, 'type': 'text'}, page_content='|  421 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT MATERIALS\nDIRECT LABOR\nMANUFACTURING \nOVERHEAD\nWORK IN PROCESS \nINVENTORY\nFINISHED GOODS\nINVENTORY\nCOST OF GOODS\nSOLD\nJOB COSTING SYSTEM\nJob costing is a costing system that accumulates costs and assigns them to speciﬁc jobs, customers, projects, or\ncontracts. The basic supporting document (usually in electronic form) in a job costing system is the job cost sheet.'),
#   Document(metadata={'page': 28, 'type': 'text'}, page_content='It records and summarizes the costs of direct materials, direct labor, and factory overhead for a particular job.\nA job costing system is used by companies that produce unique products or jobs. Examples of companies that use\njob costing systems include Boeing (airplanes), Lockheed Martin (advanced technology systems), and Deloitte &\nTouche (accounting).'),
#   Document(metadata={'page': 28, 'type': 'image', 'image_id': 'page_28_img_0'}, page_content='[Image: page_28_img_0]'),
#   Document(metadata={'page': 29, 'type': 'text'}, page_content='|  422 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#   Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_0'}, page_content='[Image: page_29_img_0]'),
#   Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_1'}, page_content='[Image: page_29_img_1]'),
#   Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_2'}, page_content='[Image: page_29_img_2]'),
#   Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_3'}, page_content='[Image: page_29_img_3]'),
#   Document(metadata={'page': 29, 'type': 'image', 'image_id': 'page_29_img_4'}, page_content='[Image: page_29_img_4]'),
#   Document(metadata={'page': 30, 'type': 'text'}, page_content='|  423 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#   Document(metadata={'page': 30, 'type': 'image', 'image_id': 'page_30_img_0'}, page_content='[Image: page_30_img_0]'),
#   Document(metadata={'page': 30, 'type': 'image', 'image_id': 'page_30_img_1'}, page_content='[Image: page_30_img_1]'),
#   Document(metadata={'page': 31, 'type': 'text'}, page_content='|  424 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT LABOR\nTRACED\nTRACED\nMANUFACTURING OVERHEAD\nALLOCATED\nOUTWORK\nTRACED\nCOST OF GOODS SOLD\nFINISHED PRODUCT\nCost of\ncompleted\nwork\nASSETS\nWORK IN PROCESS\nFLOW OF COSTS IN JOB COST SYSTEM\nRAW MATERIALS'),
#   Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_0'}, page_content='[Image: page_31_img_0]'),
#   Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_1'}, page_content='[Image: page_31_img_1]'),
#   Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_2'}, page_content='[Image: page_31_img_2]'),
#   Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_3'}, page_content='[Image: page_31_img_3]'),
#   Document(metadata={'page': 31, 'type': 'image', 'image_id': 'page_31_img_4'}, page_content='[Image: page_31_img_4]'),
#   Document(metadata={'page': 32, 'type': 'text'}, page_content='|  425 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB COSTING SYSTEM'),
#   Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_0'}, page_content='[Image: page_32_img_0]'),
#   Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_1'}, page_content='[Image: page_32_img_1]'),
#   Document(metadata={'page': 32, 'type': 'image', 'image_id': 'page_32_img_2'}, page_content='[Image: page_32_img_2]'),
#   Document(metadata={'page': 33, 'type': 'text'}, page_content='|  426 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nRAW MATERIALS\nOUTWORK\nSUPPLIES WITH \nIINSTALLATION\nDIRECT LABOR\nPHYSICAL SPACES\nUTILITY COSTS\nTRAVEL COSTS\nOTHER COSTS\nANCILLARY \nSERVICES\nBUILDING\nSHARED \nEQUIPMENT\nPROCUREMENT\nINBOUND \nLOGISTIC\nSTORAGE\nSALES\nENGENEERING\nCARPENTRY\nSHEET METAL\nELEMETS\nASSEMBLY\nREAL LIFE EXAMPLE\nINCOME STATEMENT'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_0'}, page_content='[Image: page_33_img_0]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_1'}, page_content='[Image: page_33_img_1]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_2'}, page_content='[Image: page_33_img_2]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_3'}, page_content='[Image: page_33_img_3]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_4'}, page_content='[Image: page_33_img_4]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_5'}, page_content='[Image: page_33_img_5]'),
#   Document(metadata={'page': 33, 'type': 'image', 'image_id': 'page_33_img_6'}, page_content='[Image: page_33_img_6]'),
#   Document(metadata={'page': 34, 'type': 'text'}, page_content='|  427 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFLOW OF DOCUMENTS'),
#   Document(metadata={'page': 34, 'type': 'image', 'image_id': 'page_34_img_0'}, page_content='[Image: page_34_img_0]'),
#   Document(metadata={'page': 34, 'type': 'image', 'image_id': 'page_34_img_1'}, page_content='[Image: page_34_img_1]'),
#   Document(metadata={'page': 35, 'type': 'text'}, page_content='|  428 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nDIRECT MATERIALS\nDIRECT LABOR\nMANUFACTURING \nOVERHEAD\nWORK IN PROCESS\nSTAGE  # 2\nINVENTORY\nFINISHED GOODS\nINVENTORY\nCOST OF GOODS\nSOLD\nWORK IN PROCESS\nSTAGE  # 1\nINVENTORY\nWORK IN PROCESS\nSTAGE  # 3\nINVENTORY\nPROCESS COSTING SYSTEM\nProcess costing is a product costing system that accumulates costs according to processes or departments and'),
#   Document(metadata={'page': 35, 'type': 'text'}, page_content='assigns them to a large number of nearly identical products. A process costing system is used by companies that\nemploys a standardized production process to manufacture homogeneous products . Examples of companies that\nuse process costing include Chevron Corporation (petroleum products), the Wrigley Company (chewing gum),\nand Pittsburgh Paints (paint).\nDEPARTMENT\n“A”\nDEPARTMENT\n“B”\nDEPARTMENT\n“C”'),
#   Document(metadata={'page': 35, 'type': 'image', 'image_id': 'page_35_img_0'}, page_content='[Image: page_35_img_0]'),
#   Document(metadata={'page': 36, 'type': 'text'}, page_content='|  429 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COSTING SYSTEM'),
#   Document(metadata={'page': 36, 'type': 'image', 'image_id': 'page_36_img_0'}, page_content='[Image: page_36_img_0]'),
#   Document(metadata={'page': 36, 'type': 'image', 'image_id': 'page_36_img_1'}, page_content='[Image: page_36_img_1]'),
#   Document(metadata={'page': 37, 'type': 'text'}, page_content='|  430 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nPROCESS COSTING SYSTEM'),
#   Document(metadata={'page': 37, 'type': 'image', 'image_id': 'page_37_img_0'}, page_content='[Image: page_37_img_0]'),
#   Document(metadata={'page': 37, 'type': 'image', 'image_id': 'page_37_img_1'}, page_content='[Image: page_37_img_1]'),
#   Document(metadata={'page': 38, 'type': 'text'}, page_content='|  431 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFLOW OF COSTS IN PROCESS COST SYSTEM\nDIRECT LABOR\nMANUFACTURING OVERHEAD\nCOST OF GOODS SOLD\nFINISHED\nPRODUCT \nFINISHED PRODUCT\nCosts\ntransferred\nout to\nCosts\ntransferred\nout to\nCost of\ncompleted\nwork\nTRACED\nTRACED\nALLOCATED\nASSETS\nBLENDING STATION\nWORK IN PROCESS\nFILLING STATION\nWORK IN PROCESS\nLABELING  STATION\nWORK IN PROCESS\nRAW MATERIALS'),
#   Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_0'}, page_content='[Image: page_38_img_0]'),
#   Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_1'}, page_content='[Image: page_38_img_1]'),
#   Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_2'}, page_content='[Image: page_38_img_2]'),
#   Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_3'}, page_content='[Image: page_38_img_3]'),
#   Document(metadata={'page': 38, 'type': 'image', 'image_id': 'page_38_img_4'}, page_content='[Image: page_38_img_4]'),
#   Document(metadata={'page': 39, 'type': 'text'}, page_content='|  432 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nJOB ORDER VERSUS PROCESS COST SYSTEMS'),
#   Document(metadata={'page': 39, 'type': 'image', 'image_id': 'page_39_img_0'}, page_content='[Image: page_39_img_0]'),
#   Document(metadata={'page': 39, 'type': 'image', 'image_id': 'page_39_img_1'}, page_content='[Image: page_39_img_1]'),
#   Document(metadata={'page': 40, 'type': 'text'}, page_content='|  433 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nFINANCIAL ACCOUNTING  \nMANAGERIAL ACCOUNTING  \n§\nReports to those outside the \norganiza0on:\nOwners\nCreditors\nTax Authori0es\nRegulators\n§\nEmphasizes ﬁnancial consequence \nof past ac0vi0es\n§\nEmphasizes precision\n§\nEmphasizes companywide reports \n(focus on the whole)\n§\nMust follow GAAP/IFRS\n§\nMandatory for external reports.\n§\nReports to manager inside the \norganiza0on for\nPlanning\nControlling\n§\nEmphasizes decisions aﬀec0ng the'),
#   Document(metadata={'page': 40, 'type': 'text'}, page_content='organiza0on for\nPlanning\nControlling\n§\nEmphasizes decisions aﬀec0ng the \nfuture\n§\nEmphasizes ,meliness\n§\nEmphasizes segment reports (focus \non parts)\n§\nNeed not follow GAAP/IFRS\n§\nNot mandatory\nFINANCIAL ACCOUNTING VS. MANAGERIAL ACCOUNTING\nSOURCE: Adapted from Garrison, Noreen, Brewer,  “Managerial Accounting”, 16th Edition\n“suppor0ng documents” are normally needed \n(receipts, invoices, proofs of payment, etc.)'),
#   Document(metadata={'page': 40, 'type': 'image', 'image_id': 'page_40_img_0'}, page_content='[Image: page_40_img_0]'),
#   Document(metadata={'page': 41, 'type': 'text'}, page_content='|  434 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nCOSTS\nAll resources that are sacriﬁced or\nforgone in order to achieve a\nspeciﬁc objective.\nOPPORTUNITY COSTS \nForgone beneﬁts that could have been realized for the \nbest forgone alternative use of an actual resource\nEXPENSES\nCosts of assets consumed, or services used in the \nprocess of earning revenue. \nSOME BASIC DEFINITIONS'),
#   Document(metadata={'page': 41, 'type': 'image', 'image_id': 'page_41_img_0'}, page_content='[Image: page_41_img_0]'),
#   Document(metadata={'page': 42, 'type': 'text'}, page_content='|  435 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nINPUT MEASUREMENT BASE\nACTUAL COSTING SYSTEM\nDIRECT COST\nNORMAL COSTING SYSTEM\nSTANDARD COSTING SYSTEM\nINDIRECT COST\nActual\nActual\nActual\nStandard\nStandard\nStandard'),
#   Document(metadata={'page': 42, 'type': 'image', 'image_id': 'page_42_img_0'}, page_content='[Image: page_42_img_0]'),
#   Document(metadata={'page': 43, 'type': 'text'}, page_content='|  436 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nThe most accurate alloca0on can be made only when total overhead cost is known—and that is not un0l the\nend of the period. But managers cannot wait that long for product cost informa0on. So the predetermined\nmanufacturing overhead rate is calculated before the period begins. Companies use this predetermined rate\nto allocate es0mated overhead cost to individual jobs. The predetermined manufacturingoverhead rate is'),
#   Document(metadata={'page': 43, 'type': 'text'}, page_content='based on two factors:\n§ Total es0mated manufacturing overhead costs for the period (in Smart Touch’s case, one year)\n§ Total es0mated quan0ty of the manufacturing overhead alloca0on base\nThe key to alloca0ng (assigning) indirect manufacturing costs to jobs is to iden0fy a workable manufacturing\noverhead alloca0on base. The alloca0on base is a common denominator that links overhead costs to the'),
#   Document(metadata={'page': 43, 'type': 'text'}, page_content='products. Ideally, the alloca0on base is the primary cost driver of manufacturing overhead—that is, the\nmore “alloca0on base,” the more overhead costs and vice-versa. As the phrase implies, a cost driver is the\nprimary factor that causes (drives) a cost. Tradi0onally, manufacturing companies have used the following as\ncost drivers (alloca0on bases):\n• Direct labor hours (for labor-intensive produc0on environments)\n• Direct labor cost (for labor-intensive produc0on environments)'),
#   Document(metadata={'page': 43, 'type': 'text'}, page_content='• Direct labor cost (for labor-intensive produc0on environments)\n• Machine hours (for machine-intensive produc0on environments)\nPREDETERMINED MANUFACTURING OVERHEAD RATE'),
#   Document(metadata={'page': 43, 'type': 'image', 'image_id': 'page_43_img_0'}, page_content='[Image: page_43_img_0]'),
#   Document(metadata={'page': 43, 'type': 'image', 'image_id': 'page_43_img_1'}, page_content='[Image: page_43_img_1]'),
#   Document(metadata={'page': 44, 'type': 'text'}, page_content='|  437 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq In financial accounting, the typical cost objects are finished and semi-finished\nproducts. These “entities” are tangible resources with an economic value that\nare controllable by the company that produces them and, therefore, can be\nfound in the financial statements as assets. This means that the costs that are\nattributable to the products (both finished and semi-finished) can also be'),
#   Document(metadata={'page': 44, 'type': 'text'}, page_content='attributable to the products (both finished and semi-finished) can also be\n“inventoried” (that is to say their “amount” can be added to a stock inventory\nand therefore subtracted from the formation of the economic result) if the\nunits to which they are allocated are still present in the inventory.\nq Cost\nobjects\nused\nin\nmanagerial\ncosting\ndo\nnot\nalways\nhave\nthese\ncharacteristics. There are, for example, cost objects such as activities'),
#   Document(metadata={'page': 44, 'type': 'text'}, page_content='do\nnot\nalways\nhave\nthese\ncharacteristics. There are, for example, cost objects such as activities\nperformed, or customers served, or sales channels used, or others that cannot\nbe reported as assets on the balance sheet. For this reason, for the purposes\nof the reasoning that we are about to do, we must begin by distinguishing the\nset of costs that can be attributed to a specific cost object from its possible\nsubset that contains “inventoriable costs” (that is to say costs that can be'),
#   Document(metadata={'page': 44, 'type': 'text'}, page_content='subset that contains “inventoriable costs” (that is to say costs that can be\nactually “offset” by a corresponding increase in the value of inventories ).\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#   Document(metadata={'page': 44, 'type': 'image', 'image_id': 'page_44_img_0'}, page_content='[Image: page_44_img_0]'),
#   Document(metadata={'page': 45, 'type': 'text'}, page_content='|  438 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq The “cost collec(on and alloca(on process” can be viewed as a set of cost\naccumula(on and alloca(on steps. We can think of the accumula(on phases\nas the arrival and departure points of the process (but also the intermediate\nstopping points) while the alloca(on phases represent the moments of\nmovement from a speciﬁc point to the next one.\nq The wording "cost accumula(on" iden(ﬁes the ac(vi(es of collec(ng a set of'),
#   Document(metadata={'page': 45, 'type': 'text'}, page_content='q The wording "cost accumula(on" iden(ﬁes the ac(vi(es of collec(ng a set of\ncosts that refer to the same cost object. This means that normally the “cost” of\na cost object is a compound cost, consis(ng of the sum of several elementary\ncosts.\nq The wording "cost alloca(on" iden(ﬁes, instead, the transfer of a cost value\npreviously recorded in rela(on to a cost object, to a subsequent cost object.\nq As you certainly know, ﬂow chart is a picture of the separate steps of a process'),
#   Document(metadata={'page': 45, 'type': 'text'}, page_content='q As you certainly know, ﬂow chart is a picture of the separate steps of a process\nin sequen(al order. Well, the “cost collec(on and alloca(on process” can be\neﬀec(vely represented thanks to the employment of a ﬂow chart in which the\nstages are the moments of cost accumula(on, and the vectors are the phases\nof cost alloca(on.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#   Document(metadata={'page': 45, 'type': 'image', 'image_id': 'page_45_img_0'}, page_content='[Image: page_45_img_0]'),
#   Document(metadata={'page': 46, 'type': 'text'}, page_content='|  439 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq In order to be truly eﬀec(ve, a process of accumula(on and alloca(on of costs\nmust portray as realis(cally as possible the ﬂow of ac(vi(es that make up the\nproduc(on process. In fact, it is these ac(vi(es, and the ways in which they are\ncarried out, that determine the transfer of the value contained in the resources\nﬁrst to the WIP and then to the ﬁnished products and from these eventually to\nthe customers.'),
#   Document(metadata={'page': 46, 'type': 'text'}, page_content='ﬁrst to the WIP and then to the ﬁnished products and from these eventually to\nthe customers.\nq Clearly, the ac(vi(es that deﬁne produc(on processes take a diﬀerent form\ndepending\non\nthe\ntechnology\nemployed\nand\nthe\nproduc(on\nprocess\nundertaken. The process of cost alloca(on must, therefore, respect these\nspeciﬁci(es and cannot take place in a standardized way, i.e., using using the\nsame structure regardless of the speciﬁc process developed.'),
#   Document(metadata={'page': 46, 'type': 'text'}, page_content='same structure regardless of the speciﬁc process developed.\nq They exist but of the general archetypes that can be used like bases of\nreference in order to dis(nguish two various modali(es to conﬁgure the\nproduc(ve ac(vi(es and therefore the ﬂow of accumula(on and aaribu(on of\nthe costs. These are: the “job cos(ng system”, used by companies that produce\nunique products or jobs, and “process cos(ng system” used instead by\ncompanies that employs a standardized produc(on process to manufacture'),
#   Document(metadata={'page': 46, 'type': 'text'}, page_content='companies that employs a standardized produc(on process to manufacture\nhomogeneous products.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#   Document(metadata={'page': 46, 'type': 'image', 'image_id': 'page_46_img_0'}, page_content='[Image: page_46_img_0]'),
#   Document(metadata={'page': 47, 'type': 'text'}, page_content='|  440 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq There are three methods managers and accountants can use to calculate\nproduct unit cost:\n§\nActual costing method,\n§\nNormal costing method, or\n§\nStandard costing method.\nq The actual costing method uses the actual costs of direct materials, direct\nlabor, and overhead when they become known to calculate the product unit\ncost. This means, many times, waiting until the end of the period when all the'),
#   Document(metadata={'page': 47, 'type': 'text'}, page_content='cost. This means, many times, waiting until the end of the period when all the\ncost data are available. For most companies, this is not practical.\nq The normal costing method combines the easy-to-track actual direct costs of\nmaterials and labour with estimated overhead costs to determine a product\nunit cost. The use of this costing method is widespread, since many overhead\nbills, such as utility bills, are not received until after products or services are'),
#   Document(metadata={'page': 47, 'type': 'text'}, page_content='bills, such as utility bills, are not received until after products or services are\nproduced and sold. For this reason, normal costing system that uses actual\ncosts for direct materials, direct labour and other direct costs and applies\nindirect costs using a predetermined overhead cost rate.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#   Document(metadata={'page': 47, 'type': 'image', 'image_id': 'page_47_img_0'}, page_content='[Image: page_47_img_0]'),
#   Document(metadata={'page': 48, 'type': 'text'}, page_content='|  441 |\nBRUNO DE ROSA – PARTNER E SCIENTIFIC DIRECTOR DYN@MIKA S.R.L.\nq To compute the predetermined overhead rate, four steps are needed:\n1. Es(mate total overhead costs for the opera(ng period, usually a year.\n2. Select the most appropriate alloca(on base (i.e. the basis that best\nreﬂects the cause-eﬀect rela(onship that links indirect costs to the\nchosen cost object)\n3. Es(mate the total amount of the chosen alloca(on base for the opera(ng \nperiod.'),
#   Document(metadata={'page': 48, 'type': 'text'}, page_content='3. Es(mate the total amount of the chosen alloca(on base for the opera(ng \nperiod.\n4. Divide the es(mated  total overhead costs by the es(mated amount of \nthe chosen alloca(on base to obtain the predetermined overhead rate.\nq The standard cos(ng method uses es(mated or standard costs of direct\nmaterials, direct labour, and overhead to calculate the product unit cost. This\nmethod is used because managers some(mes need product cost informa(on'),
#   Document(metadata={'page': 48, 'type': 'text'}, page_content='method is used because managers some(mes need product cost informa(on\nbefore the accoun(ng period begins so that they can control the cost of\nopera(ng ac(vi(es or price a proposed product for a customer. In such\nsitua(ons, product unit costs must be es(mated, and the standard cos(ng\nmethod can be helpful. Moreover, standard cos(ng is very useful in\nperformance management and evalua(on because a manager can compare\nactual and standard costs to compute the variances. In such a way it becomes a'),
#   Document(metadata={'page': 48, 'type': 'text'}, page_content='actual and standard costs to compute the variances. In such a way it becomes a\ntool for exercise a form of steering control and can be used for learning.\nSOME TAKEAWAY POINTS FROM MODULE # 8'),
#   Document(metadata={'page': 48, 'type': 'image', 'image_id': 'page_48_img_0'}, page_content='[Image: page_48_img_0]')],
#  array([[-0.04622868,  0.01753438,  0.03629856, ..., -0.08006593,
#          -0.01380648, -0.00609296],
#         [-0.02515623, -0.02274406,  0.05144298, ...,  0.01638889,
#           0.01698227, -0.05855679],
#         [-0.0089438 ,  0.00232195, -0.00363326, ...,  0.06655418,
#          -0.0269383 , -0.01064131],
#         ...,
#         [ 0.0050875 ,  0.01034724, -0.00103213, ...,  0.00999359,
#           0.02369087,  0.00190299],
#         [-0.00482922,  0.00452271, -0.01624018, ..., -0.05643078,
#           0.02530663,  0.00100464],
#         [-0.02515623, -0.02274406,  0.05144298, ...,  0.01638889,
#           0.01698227, -0.05855679]], dtype=float32))

# %%
# Create custom FAISS index since we have precomputed embeddings
vector_store = FAISS.from_embeddings(
    text_embeddings=[(doc.page_content, emb) for doc, emb in zip(all_docs, embeddings_array)],
    embedding=None,  # using precomputed embeddings
    metadatas=[doc.metadata for doc in all_docs]
)
vector_store
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# %pip install -U langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.8-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.3.76)
# Collecting groq<1,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.32.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (2.11.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.4.28)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.5.0)
# Downloading langchain_groq-0.3.8-py3-none-any.whl (16 kB)
# Downloading groq-0.32.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.32.0 langchain-groq-0.3.8

# %%
# Initialize GROQ model
# from langchain.chat_models import init_chat_model # This import is already present in cell a3621417
llm = init_chat_model("groq:meta-llama/llama-4-scout-17b-16e-instruct") # Change model to the specified GROQ model
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x7d8e1885a3c0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7d8e196cfb60>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
def retrieve_multimodal(query, k=5):
    """Unified retrieval using CLIP embeddings for both text and images."""
    # Embed query using CLIP
    query_embedding = embed_text(query)

    # Search in unified vector store
    results = vector_store.similarity_search_by_vector(
        embedding=query_embedding,
        k=k
    )

    return results

# %%
def create_multimodal_message(query, retrieved_docs):
    """Create a message with both text and images for GPT-4V."""
    content = []

    # Add the query
    content.append({
        "type": "text",
        "text": f"Question: {query}\n\nContext:\n"
    })

    # Separate text and image documents
    text_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "text"]
    image_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "image"]

    # Add text context
    if text_docs:
        text_context = "\n\n".join([
            f"[Page {doc.metadata['page']}]: {doc.page_content}"
            for doc in text_docs
        ])
        content.append({
            "type": "text",
            "text": f"Text excerpts:\n{text_context}\n"
        })

    # Add images
    for doc in image_docs:
        image_id = doc.metadata.get("image_id")
        if image_id and image_id in image_data_store:
            content.append({
                "type": "text",
                "text": f"\n[Image from page {doc.metadata['page']}]:\n"
            })
            content.append({
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{image_data_store[image_id]}"
                }
            })

    # Add instruction
    content.append({
        "type": "text",
        "text": "\n\nPlease answer the question based on the provided text and images."
    })

    return HumanMessage(content=content)

# %%
def multimodal_pdf_rag_pipeline(query):
    """Main pipeline for multimodal RAG."""
    # Retrieve relevant documents
    context_docs = retrieve_multimodal(query, k=5)

    # Create multimodal message
    message = create_multimodal_message(query, context_docs)

    # Get response from GPT-4V
    response = llm.invoke([message])

    # Print retrieved context info
    print(f"\nRetrieved {len(context_docs)} documents:")
    for doc in context_docs:
        doc_type = doc.metadata.get("type", "unknown")
        page = doc.metadata.get("page", "?")
        if doc_type == "text":
            preview = doc.page_content[:100] + "..." if len(doc.page_content) > 100 else doc.page_content
            print(f"  - Text from page {page}: {preview}")
        else:
            print(f"  - Image from page {page}")
    print("\n")

    return response.content

# %%
if __name__ == "__main__":
    # Example queries
    queries = [
        "What are the different types of efficiency discussed in the document?",
        "What are the main steps of a typical income statement shown in the document?",
        "What are the different profit margins in the income statement (Sales → EAT breakdown)?",
        "What is the EBIT margin in the example income statement?",
        "In the job order costing table, what is subtracted to reach the ‘First Margin’?"
    ]

    for query in queries:
        print(f"\nQuery: {query}")
        print("-" * 50)
        # Use of the llm object,GROQ model
        answer = multimodal_pdf_rag_pipeline(query)
        print(f"Answer: {answer}")
        print("=" * 70)
# Out:
# Query: What are the different types of efficiency discussed in the document?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 18: Focused on cost-objects that are considered
# particularly relevant for day-by-day decisions
# and, ther...
#   - Text from page 11: into categories that remind us the type of resources purchased or consumed
# (e.g., raw materials, dep...
#   - Text from page 6: more modern management control. The
# focus is on the outside world.
# Those who adopt this perspective ...
#   - Text from page 13: more modern management control. The
# focus is on the outside world.
# Those who adopt this perspective ...
#   - Text from page 44: do
# not
# always
# have
# these
# characteristics. There are, for example, cost objects such as activities
# pe...
#
#
# Answer: ## Types of Efficiency Discussed
#
# The provided text excerpts relate to cost analysis, cost accumulation, and cost assignment in the context of management control. However, they do not explicitly discuss different types of efficiency.
#
# ### Inferred Types of Efficiency
#
# Based on the context of cost analysis and management control, the following types of efficiency can be inferred:
#
# 1. **Cost Efficiency**: This refers to minimizing costs while achieving a specific goal or objective. It involves optimizing cost accumulation and assignment to achieve cost-effectiveness.
#
# 2. **Operational Efficiency**: This involves maximizing output while minimizing waste and optimizing resource utilization. It can be related to cost objects such as activities performed, customers served, or sales channels used.
#
# 3. **Allocative Efficiency**: This refers to allocating resources to their most valuable uses. In the context of cost analysis, it involves assigning costs to cost objects in a way that reflects their relative importance or value.
#
# 4. **Technical Efficiency**: This involves maximizing output given a set of inputs. In the context of cost analysis, it involves optimizing the use of resources to achieve a specific output.
#
# ### Conclusion
#
# While the provided text excerpts do not explicitly discuss different types of efficiency, the context of cost analysis and management control suggests that the above types of efficiency are relevant. A more detailed analysis of the specific document or text in question would be necessary to provide a more accurate answer.
#
# In general, efficiency can be categorized into several types, including:
#
# * **Economic Efficiency**: Achieving a given output at the lowest possible cost.
# * **Technical Efficiency**: Achieving the maximum possible output from a given set of inputs.
# * **Allocative Efficiency**: Allocating resources to their most valuable uses.
# * **Dynamic Efficiency**: Achieving efficiency over time, considering changes in technology, demand, and other factors.
# * **X-Efficiency**: Achieving efficiency in the presence of imperfect information, uncertainty, and other real-world complexities.
#
# These types of efficiency are not explicitly mentioned in the provided text excerpts, but they are relevant to the broader context of management control and cost analysis.
#
# The best answer is:
#
# * Cost Efficiency
# * Operational Efficiency
# * Allocative Efficiency
# * Technical Efficiency
# ======================================================================
#
# Query: What are the main steps of a typical income statement shown in the document?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 44: do
# not
# always
# have
# these
# characteristics. There are, for example, cost objects such as activities
# pe...
#   - Text from page 11: into categories that remind us the type of resources purchased or consumed
# (e.g., raw materials, dep...
#   - Text from page 5: MANAGERIAL ACCOUNTING and
# MANAGERIAL COSTING
# Partial Financial Productivity
# Financial and
# nonfinan...
#   - Text from page 10: MANAGERIAL ACCOUNTING and
# MANAGERIAL COSTING
# Partial Financial Productivity
# Financial and
# nonﬁnanc...
#   - Text from page 12: – for the cost object)
# §
# Structure of the cost ﬂow: selec.on of the proper accumula.on’s method
# §
# In...
#
#
# Answer: ## Main Steps of a Typical Income Statement
#
# Based on the provided text excerpts, specifically the partial financial productivity statement on [Page5] and [Page10], the main steps of a typical income statement are:
#
# ### 1. Operating Revenues
# The first step is to report the operating revenues, which in this case is €4,207,565.
#
# ### 2. Operating Costs
# The second step is to report the operating costs, which in this case is €3,705,816.
#
# ### 3. Operating Profit
# The third step is to calculate the operating profit by subtracting the operating costs from the operating revenues, which in this case is €501,749 (€4,207,565 - €3,705,816).
#
# These three steps provide a concise overview of a typical income statement.
#
# ### Conclusion
# In conclusion, a typical income statement consists of operating revenues, operating costs, and operating profit. These steps are essential in providing a financial snapshot of a company's performance.
#
# Please let me know if I can help you with anything else.
# ======================================================================
#
# Query: What are the different profit margins in the income statement (Sales → EAT breakdown)?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 11: into categories that remind us the type of resources purchased or consumed
# (e.g., raw materials, dep...
#   - Text from page 22: NO
# ASSET
# + Sales
#    xxx.xxx
# - Cost from the use of the asset xxx.xxx
# = First margin
#       xxx.xxx
# - ...
#   - Text from page 12: – for the cost object)
# §
# Structure of the cost ﬂow: selec.on of the proper accumula.on’s method
# §
# In...
#   - Text from page 21: be a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The
# resul'ng unit cos...
#   - Text from page 10: MANAGERIAL ACCOUNTING and
# MANAGERIAL COSTING
# Partial Financial Productivity
# Financial and
# nonﬁnanc...
#
#
# Answer: Based on the provided text, I will outline the different profit margins in the income statement, specifically the breakdown from Sales to Earnings After Taxes (EAT), also known as Net Income.
#
# Here's the typical breakdown:
#
# 1. **Sales (or Operating Revenues)**: The starting point, which is €4,207,565 in the example.
# 2. **First Margin (or Gross Margin)**: Sales - Cost of Goods Sold (COGS) or Cost from the use of the asset.
#    - In the example, this is not explicitly shown, but we can infer it.
# 3. **Cost Object Margin**: First Margin - Other cost object's costs.
#    - Not explicitly shown but implied in the sequence.
# 4. **EBIT (Earnings Before Interest and Taxes)**:
#    - In the sequence provided: Sales - Cost from the use of the asset - Other cost object's costs - Other costs = EBIT.
#    - In the example on page 10: Operating Revenues - Operating costs = Operating profit (€501,749).
# 5. **EBITDA (Earnings Before Interest, Taxes, Depreciation, and Amortization)**: Not directly shown but can be inferred as EBIT + Depreciation + Amortization.
# 6. **Earnings Before Taxes (EBT)**: EBIT - Interest Expenses.
# 7. **Earnings After Taxes (EAT) or Net Income**: EBT - Taxes.
#
# The provided text does not explicitly list all these steps with corresponding numerical values but implies a sequence that starts with Sales and deducts various costs to arrive at a final profit figure, which is presumably EAT or Net Income.
#
# The sequence hinted at on page 22 outlines:
# - Sales
# - Less: Cost from the use of the asset = First margin
# - Less: Other cost object’s costs = Cost object margin
# - Less: Other costs = EBIT
#
# This breakdown helps in understanding the profitability of a company at different levels, from the gross margin (which focuses on the direct costs of producing goods or services) down to net income (which reflects all expenses, including taxes and interest).
# ======================================================================
#
# Query: What is the EBIT margin in the example income statement?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 22: NO
# ASSET
# + Sales
#    xxx.xxx
# - Cost from the use of the asset xxx.xxx
# = First margin
#       xxx.xxx
# - ...
#   - Text from page 24: xxx.xxx
# = Cost object margin
# xxx.xxx
# - Other costs
# xxx.xxx
# = EBIT
# xxx.xxx
# YES
# Are the condi0on for
# ...
#   - Text from page 11: into categories that remind us the type of resources purchased or consumed
# (e.g., raw materials, dep...
#   - Text from page 21: be a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The
# resul'ng unit cos...
#   - Text from page 5: MANAGERIAL ACCOUNTING and
# MANAGERIAL COSTING
# Partial Financial Productivity
# Financial and
# nonfinan...
#
#
# Answer: To find the EBIT margin from the provided text, we first need to understand what EBIT margin is. The EBIT (Earnings Before Interest and Taxes) margin is a financial metric that measures a company's profitability by calculating the ratio of EBIT to sales. The formula for EBIT margin is:
#
# EBIT Margin = (EBIT / Sales) * 100
#
# From the text on Page 5, we have:
#
# - Sales (Operating revenues): €4,207,565
# - Operating costs: €3,705,816
# - Operating profit: €501,749
#
# Given that "Operating profit" in this context likely corresponds to EBIT (since it's calculated before interest and taxes, which are not mentioned), we can proceed with the calculation.
#
# EBIT = €501,749
# Sales = €4,207,565
#
# EBIT Margin = (€501,749 / €4,207,565) * 100
#
# Calculating the EBIT margin:
#
# EBIT Margin = (501,749 / 4,207,565) * 100 ≈ 11.93%
#
# Therefore, the EBIT margin in the example income statement is approximately 11.93%.
# ======================================================================
#
# Query: In the job order costing table, what is subtracted to reach the ‘First Margin’?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 44: attributable to the products (both finished and semi-finished) can also be
# “inventoried” (that is to...
#   - Text from page 11: into categories that remind us the type of resources purchased or consumed
# (e.g., raw materials, dep...
#   - Text from page 18: Focused on cost-objects that are considered
# particularly relevant for day-by-day decisions
# and, ther...
#   - Text from page 48: method is used because managers some(mes need product cost informa(on
# before the accoun(ng period be...
#   - Text from page 21: be a<ached to the units produced for external ﬁnancial repor7ng under US GAAP. The
# resul'ng unit cos...
#
#
# Answer: Based on the context of job order costing, to reach the 'First Margin', the **Cost of Goods Sold** or specifically the **Direct Costs** or **Prime Costs** (which include direct materials, direct labor) are subtracted from the **Sales Revenue** or the total value of goods sold.
#
# However, more accurately in the context typically found in job order costing and similar systems:
#
# The **First Margin** often refers to the calculation after deducting the direct costs associated with producing the goods or providing the service. Therefore, to reach the 'First Margin', **Direct Costs** are subtracted.
#
# Given typical calculations:
# 1. **Sales Revenue**
# 2. Less: **Direct Costs** (or **Prime Costs**, which could include direct materials and direct labor)
#    = **First Margin** (also known as Contribution Margin in some contexts, but here specifically tailored to direct costs)
#
# The exact terminology might slightly vary depending on the specific costing system or company practices. However, in general managerial accounting terms, the First Margin, often akin to a contribution margin concept, would see the subtraction of variable or direct costs from sales to arrive at a margin.
#
# In job order costing specifically, detailed tracking of costs per job allows for precise calculation of direct costs attributable to each job, facilitating the computation of the First Margin as direct costs are subtracted from revenues generated by the job.
#
# Therefore, to directly answer based on standard practices: **Direct Costs** are subtracted to reach the ‘First Margin’.
# ======================================================================

# %%
# Install git
# !apt-get install -qq git

# Clone  repo into Colab
# !git clone https://github.com/loryneJoy/Multimodal_AI_Cost_Revenue_Analysis.git

# Copy  notebook into the repo
# !cp /content/Revenue_Analysis_Multimodal_Project.ipynb /content/Multimodal_AI_Cost_Revenue_Analysis/

# Move into repo directory
# %cd /content/Multimodal_AI_Cost_Revenue_Analysis

# Configure Git
# !git config --global user.email "lorynejoynyanchama@gmail.com"
# !git config --global user.name "loryneJoy"

# Commit changes
# !git add Revenue_Analysis_Multumodal_Project.ipynb
# !git commit -m "Added notebook from Colab"

# Push with token (replace YOUR_TOKEN_HERE with your PAT)
# !git push https://loryneJoy:YOUR_TOKEN_HERE@github.com/loryneJoy/Multimodal_AI_Cost_Revenue_Analysis.git main

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

file_path = "/content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb"
print("Exists:", os.path.exists(file_path))
print("Full path:", os.path.abspath(file_path))
# Out:
# Exists: True
# Full path: /content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb

# %%
import nbformat

# Path to your notebook - make sure this is the correct path in your Colab environment
notebook_path = "/content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb"

# Load notebook
with open(notebook_path, "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# Remove problematic widget metadata
if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

# Save cleaned notebook
with open(notebook_path, "w", encoding="utf-8") as f:
    nbformat.write(nb, f)

print(f"Cleaned notebook saved to {notebook_path}")
# Out:
# Cleaned notebook saved to /content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb

# %%
# !pip install nbstripout
# !nbstripout Multimodal_Revenue_Analysis_Project.ipynb
# Out:
# Collecting nbstripout
#   Downloading nbstripout-0.8.1-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from nbstripout) (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->nbstripout) (4.4.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->nbstripout) (4.15.0)
# Downloading nbstripout-0.8.1-py2.py3-none-any.whl (16 kB)
# Installing collected packages: nbstripout
# Successfully installed nbstripout-0.8.1
# Could not strip 'Multimodal_Revenue_Analysis_Project.ipynb': file not found

# %%
# !pip install nbstripout
# !nbstripout "/content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb"
# Out:
# Requirement already satisfied: nbstripout in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from nbstripout) (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbstripout) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbstripout) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->nbstripout) (4.4.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->nbstripout) (4.15.0)

# %%
import nbformat

# Path to the current notebook
notebook_path = "/content/drive/MyDrive/Colab Notebooks/Multimodal_Revenue_Analysis_Project.ipynb"  # replace with your filename

# Load the notebook
with open(notebook_path) as f:
    nb = nbformat.read(f, as_version=4)

# Fix metadata (remove broken widgets)
if "widgets" in nb["metadata"]:
    nb["metadata"]["widgets"]["state"] = nb["metadata"]["widgets"].get("state", {})

# Save the fixed notebook
with open(notebook_path, "w") as f:
    nbformat.write(nb, f)

print("Notebook metadata fixed ✅. Reopen the notebook now.")
# Out:
# Notebook metadata fixed ✅. Reopen the notebook now.
